# %% [markdown]
# ## check out file structure

# %%
import os

# adjust this relative path until it points at your experiment_6 results folder
RESULTS_ROOT = os.path.abspath(
    os.path.join(os.getcwd(), os.pardir, os.pardir,
                 "external_data", "nlp4neuro", "results_april30", "experiment_1")
)

print("Looking in:", RESULTS_ROOT)
for root, dirs, files in os.walk(RESULTS_ROOT):
    # only print the first two levels to keep it short
    rel = os.path.relpath(root, RESULTS_ROOT)
    depth = rel.count(os.sep)
    if depth <= 3:
        indent = "  " * depth
        print(f"{indent}{os.path.basename(root)}/")
        for f in files:
            if f.endswith(".npy") or f.endswith(".png"):
                print(f"{indent}  {f}")
# Out:
# Looking in: C:\Users\jacob\OneDrive\Documents\GitHub\external_data\nlp4neuro\results_april30\experiment_1
# experiment_1/
# fish10/
#   fish10_final_predictions_groundtruth_test.npy
#   fish10_final_predictions_groundtruth_val.npy
#   fish10_grouped_rmse_comparison.png
#   run_1/
#     seq_10/
#       fish10_final_predictions_bert_test_run1.npy
#       fish10_final_predictions_deepseek_moe_test_run1.npy
#       fish10_final_predictions_gpt2_pretrained_test_run1.npy
#       fish10_final_predictions_lstm_test_run1.npy
#       fish10_final_predictions_reservoir_test_run1.npy
#     seq_15/
#       fish10_final_predictions_bert_test_run1.npy
#       fish10_final_predictions_deepseek_moe_test_run1.npy
#       fish10_final_predictions_gpt2_pretrained_test_run1.npy
#       fish10_final_predictions_lstm_test_run1.npy
#       fish10_final_predictions_reservoir_test_run1.npy
#     seq_20/
#       fish10_final_predictions_bert_test_run1.npy
#       fish10_final_predictions_deepseek_moe_test_run1.npy
#       fish10_final_predictions_gpt2_pretrained_test_run1.npy
#       fish10_final_predictions_lstm_test_run1.npy
#       fish10_final_predictions_reservoir_test_run1.npy
#     seq_5/
#       fish10_final_predictions_bert_test_run1.npy
#       fish10_final_predictions_deepseek_moe_test_run1.npy
#       fish10_final_predictions_gpt2_pretrained_test_run1.npy
#       fish10_final_predictions_lstm_test_run1.npy
#       fish10_final_predictions_reservoir_test_run1.npy
#   run_10/
#     seq_10/
#       fish10_final_predictions_bert_test_run10.npy
#       fish10_final_predictions_deepseek_moe_test_run10.npy
#       fish10_final_predictions_gpt2_pretrained_test_run10.npy
#       fish10_final_predictions_lstm_test_run10.npy
#       fish10_final_predictions_reservoir_test_run10.npy
#     seq_15/
#       fish10_final_predictions_bert_test_run10.npy
#       fish10_final_predictions_deepseek_moe_test_run10.npy
#       fish10_final_predictions_gpt2_pretrained_test_run10.npy
#       fish10_final_predictions_lstm_test_run10.npy
#       fish10_final_predictions_reservoir_test_run10.npy
#     seq_20/
#       fish10_final_predictions_bert_test_run10.npy
#       fish10_final_predictions_deepseek_moe_test_run10.npy
#       fish10_final_predictions_gpt2_pretrained_test_run10.npy
#       fish10_final_predictions_lstm_test_run10.npy
#       fish10_final_predictions_reservoir_test_run10.npy
#     seq_5/
#       fish10_final_predictions_bert_test_run10.npy
#       fish10_final_predictions_deepseek_moe_test_run10.npy
#       fish10_final_predictions_gpt2_pretrained_test_run10.npy
#       fish10_final_predictions_lstm_test_run10.npy
#       fish10_final_predictions_reservoir_test_run10.npy
#   run_2/
#     seq_10/
#       fish10_final_predictions_bert_test_run2.npy
#       fish10_final_predictions_deepseek_moe_test_run2.npy
#       fish10_final_predictions_gpt2_pretrained_test_run2.npy
#       fish10_final_predictions_lstm_test_run2.npy
#       fish10_final_predictions_reservoir_test_run2.npy
#     seq_15/
#       fish10_final_predictions_bert_test_run2.npy
#       fish10_final_predictions_deepseek_moe_test_run2.npy
#       fish10_final_predictions_gpt2_pretrained_test_run2.npy
#       fish10_final_predictions_lstm_test_run2.npy
#       fish10_final_predictions_reservoir_test_run2.npy
#     seq_20/
#       fish10_final_predictions_bert_test_run2.npy
#       fish10_final_predictions_deepseek_moe_test_run2.npy
#       fish10_final_predictions_gpt2_pretrained_test_run2.npy
#       fish10_final_predictions_lstm_test_run2.npy
#       fish10_final_predictions_reservoir_test_run2.npy
#     seq_5/
#       fish10_final_predictions_bert_test_run2.npy
#       fish10_final_predictions_deepseek_moe_test_run2.npy
#       fish10_final_predictions_gpt2_pretrained_test_run2.npy
#       fish10_final_predictions_lstm_test_run2.npy
#       fish10_final_predictions_reservoir_test_run2.npy
#   run_3/
#     seq_10/
#       fish10_final_predictions_bert_test_run3.npy
#       fish10_final_predictions_deepseek_moe_test_run3.npy
#       fish10_final_predictions_gpt2_pretrained_test_run3.npy
#       fish10_final_predictions_lstm_test_run3.npy
#       fish10_final_predictions_reservoir_test_run3.npy
#     seq_15/
#       fish10_final_predictions_bert_test_run3.npy
#       fish10_final_predictions_deepseek_moe_test_run3.npy
#       fish10_final_predictions_gpt2_pretrained_test_run3.npy
#       fish10_final_predictions_lstm_test_run3.npy
#       fish10_final_predictions_reservoir_test_run3.npy
#     seq_20/
#       fish10_final_predictions_bert_test_run3.npy
#       fish10_final_predictions_deepseek_moe_test_run3.npy
#       fish10_final_predictions_gpt2_pretrained_test_run3.npy
#       fish10_final_predictions_lstm_test_run3.npy
#       fish10_final_predictions_reservoir_test_run3.npy
#     seq_5/
#       fish10_final_predictions_bert_test_run3.npy
#       fish10_final_predictions_deepseek_moe_test_run3.npy
#       fish10_final_predictions_gpt2_pretrained_test_run3.npy
#       fish10_final_predictions_lstm_test_run3.npy
#       fish10_final_predictions_reservoir_test_run3.npy
#   run_4/
#     seq_10/
#       fish10_final_predictions_bert_test_run4.npy
#       fish10_final_predictions_deepseek_moe_test_run4.npy
#       fish10_final_predictions_gpt2_pretrained_test_run4.npy
#       fish10_final_predictions_lstm_test_run4.npy
#       fish10_final_predictions_reservoir_test_run4.npy
#     seq_15/
#       fish10_final_predictions_bert_test_run4.npy
#       fish10_final_predictions_deepseek_moe_test_run4.npy
#       fish10_final_predictions_gpt2_pretrained_test_run4.npy
#       fish10_final_predictions_lstm_test_run4.npy
#       fish10_final_predictions_reservoir_test_run4.npy
#     seq_20/
#       fish10_final_predictions_bert_test_run4.npy
#       fish10_final_predictions_deepseek_moe_test_run4.npy
#       fish10_final_predictions_gpt2_pretrained_test_run4.npy
#       fish10_final_predictions_lstm_test_run4.npy
#       fish10_final_predictions_reservoir_test_run4.npy
#     seq_5/
#       fish10_final_predictions_bert_test_run4.npy
#       fish10_final_predictions_deepseek_moe_test_run4.npy
#       fish10_final_predictions_gpt2_pretrained_test_run4.npy
#       fish10_final_predictions_lstm_test_run4.npy
#       fish10_final_predictions_reservoir_test_run4.npy
#   run_5/
#     seq_10/
#       fish10_final_predictions_bert_test_run5.npy
#       fish10_final_predictions_deepseek_moe_test_run5.npy
#       fish10_final_predictions_gpt2_pretrained_test_run5.npy
#       fish10_final_predictions_lstm_test_run5.npy
#       fish10_final_predictions_reservoir_test_run5.npy
#     seq_15/
#       fish10_final_predictions_bert_test_run5.npy
#       fish10_final_predictions_deepseek_moe_test_run5.npy
#       fish10_final_predictions_gpt2_pretrained_test_run5.npy
#       fish10_final_predictions_lstm_test_run5.npy
#       fish10_final_predictions_reservoir_test_run5.npy
#     seq_20/
#       fish10_final_predictions_bert_test_run5.npy
#       fish10_final_predictions_deepseek_moe_test_run5.npy
#       fish10_final_predictions_gpt2_pretrained_test_run5.npy
#       fish10_final_predictions_lstm_test_run5.npy
#       fish10_final_predictions_reservoir_test_run5.npy
#     seq_5/
#       fish10_final_predictions_bert_test_run5.npy
#       fish10_final_predictions_deepseek_moe_test_run5.npy
#       fish10_final_predictions_gpt2_pretrained_test_run5.npy
#       fish10_final_predictions_lstm_test_run5.npy
#       fish10_final_predictions_reservoir_test_run5.npy
#   run_6/
#     seq_10/
#       fish10_final_predictions_bert_test_run6.npy
#       fish10_final_predictions_deepseek_moe_test_run6.npy
#       fish10_final_predictions_gpt2_pretrained_test_run6.npy
#       fish10_final_predictions_lstm_test_run6.npy
#       fish10_final_predictions_reservoir_test_run6.npy
#     seq_15/
#       fish10_final_predictions_bert_test_run6.npy
#       fish10_final_predictions_deepseek_moe_test_run6.npy
#       fish10_final_predictions_gpt2_pretrained_test_run6.npy
#       fish10_final_predictions_lstm_test_run6.npy
#       fish10_final_predictions_reservoir_test_run6.npy
#     seq_20/
#       fish10_final_predictions_bert_test_run6.npy
#       fish10_final_predictions_deepseek_moe_test_run6.npy
#       fish10_final_predictions_gpt2_pretrained_test_run6.npy
#       fish10_final_predictions_lstm_test_run6.npy
#       fish10_final_predictions_reservoir_test_run6.npy
#     seq_5/
#       fish10_final_predictions_bert_test_run6.npy
#       fish10_final_predictions_deepseek_moe_test_run6.npy
#       fish10_final_predictions_gpt2_pretrained_test_run6.npy
#       fish10_final_predictions_lstm_test_run6.npy
#       fish10_final_predictions_reservoir_test_run6.npy
#   run_7/
#     seq_10/
#       fish10_final_predictions_bert_test_run7.npy
#       fish10_final_predictions_deepseek_moe_test_run7.npy
#       fish10_final_predictions_gpt2_pretrained_test_run7.npy
#       fish10_final_predictions_lstm_test_run7.npy
#       fish10_final_predictions_reservoir_test_run7.npy
#     seq_15/
#       fish10_final_predictions_bert_test_run7.npy
#       fish10_final_predictions_deepseek_moe_test_run7.npy
#       fish10_final_predictions_gpt2_pretrained_test_run7.npy
#       fish10_final_predictions_lstm_test_run7.npy
#       fish10_final_predictions_reservoir_test_run7.npy
#     seq_20/
#       fish10_final_predictions_bert_test_run7.npy
#       fish10_final_predictions_deepseek_moe_test_run7.npy
#       fish10_final_predictions_gpt2_pretrained_test_run7.npy
#       fish10_final_predictions_lstm_test_run7.npy
#       fish10_final_predictions_reservoir_test_run7.npy
#     seq_5/
#       fish10_final_predictions_bert_test_run7.npy
#       fish10_final_predictions_deepseek_moe_test_run7.npy
#       fish10_final_predictions_gpt2_pretrained_test_run7.npy
#       fish10_final_predictions_lstm_test_run7.npy
#       fish10_final_predictions_reservoir_test_run7.npy
#   run_8/
#     seq_10/
#       fish10_final_predictions_bert_test_run8.npy
#       fish10_final_predictions_deepseek_moe_test_run8.npy
#       fish10_final_predictions_gpt2_pretrained_test_run8.npy
#       fish10_final_predictions_lstm_test_run8.npy
#       fish10_final_predictions_reservoir_test_run8.npy
#     seq_15/
#       fish10_final_predictions_bert_test_run8.npy
#       fish10_final_predictions_deepseek_moe_test_run8.npy
#       fish10_final_predictions_gpt2_pretrained_test_run8.npy
#       fish10_final_predictions_lstm_test_run8.npy
#       fish10_final_predictions_reservoir_test_run8.npy
#     seq_20/
#       fish10_final_predictions_bert_test_run8.npy
#       fish10_final_predictions_deepseek_moe_test_run8.npy
#       fish10_final_predictions_gpt2_pretrained_test_run8.npy
#       fish10_final_predictions_lstm_test_run8.npy
#       fish10_final_predictions_reservoir_test_run8.npy
#     seq_5/
#       fish10_final_predictions_bert_test_run8.npy
#       fish10_final_predictions_deepseek_moe_test_run8.npy
#       fish10_final_predictions_gpt2_pretrained_test_run8.npy
#       fish10_final_predictions_lstm_test_run8.npy
#       fish10_final_predictions_reservoir_test_run8.npy
#   run_9/
#     seq_10/
#       fish10_final_predictions_bert_test_run9.npy
#       fish10_final_predictions_deepseek_moe_test_run9.npy
#       fish10_final_predictions_gpt2_pretrained_test_run9.npy
#       fish10_final_predictions_lstm_test_run9.npy
#       fish10_final_predictions_reservoir_test_run9.npy
#     seq_15/
#       fish10_final_predictions_bert_test_run9.npy
#       fish10_final_predictions_deepseek_moe_test_run9.npy
#       fish10_final_predictions_gpt2_pretrained_test_run9.npy
#       fish10_final_predictions_lstm_test_run9.npy
#       fish10_final_predictions_reservoir_test_run9.npy
#     seq_20/
#       fish10_final_predictions_bert_test_run9.npy
#       fish10_final_predictions_deepseek_moe_test_run9.npy
#       fish10_final_predictions_gpt2_pretrained_test_run9.npy
#       fish10_final_predictions_lstm_test_run9.npy
#       fish10_final_predictions_reservoir_test_run9.npy
#     seq_5/
#       fish10_final_predictions_bert_test_run9.npy
#       fish10_final_predictions_deepseek_moe_test_run9.npy
#       fish10_final_predictions_gpt2_pretrained_test_run9.npy
#       fish10_final_predictions_lstm_test_run9.npy
#       fish10_final_predictions_reservoir_test_run9.npy
# fish11/
#   fish11_final_predictions_groundtruth_test.npy
#   fish11_final_predictions_groundtruth_val.npy
#   fish11_grouped_rmse_comparison.png
#   run_1/
#     seq_10/
#       fish11_final_predictions_bert_test_run1.npy
#       fish11_final_predictions_deepseek_moe_test_run1.npy
#       fish11_final_predictions_gpt2_pretrained_test_run1.npy
#       fish11_final_predictions_lstm_test_run1.npy
#       fish11_final_predictions_reservoir_test_run1.npy
#     seq_15/
#       fish11_final_predictions_bert_test_run1.npy
#       fish11_final_predictions_deepseek_moe_test_run1.npy
#       fish11_final_predictions_gpt2_pretrained_test_run1.npy
#       fish11_final_predictions_lstm_test_run1.npy
#       fish11_final_predictions_reservoir_test_run1.npy
#     seq_20/
#       fish11_final_predictions_bert_test_run1.npy
#       fish11_final_predictions_deepseek_moe_test_run1.npy
#       fish11_final_predictions_gpt2_pretrained_test_run1.npy
#       fish11_final_predictions_lstm_test_run1.npy
#       fish11_final_predictions_reservoir_test_run1.npy
#     seq_5/
#       fish11_final_predictions_bert_test_run1.npy
#       fish11_final_predictions_deepseek_moe_test_run1.npy
#       fish11_final_predictions_gpt2_pretrained_test_run1.npy
#       fish11_final_predictions_lstm_test_run1.npy
#       fish11_final_predictions_reservoir_test_run1.npy
#   run_10/
#     seq_10/
#       fish11_final_predictions_bert_test_run10.npy
#       fish11_final_predictions_deepseek_moe_test_run10.npy
#       fish11_final_predictions_gpt2_pretrained_test_run10.npy
#       fish11_final_predictions_lstm_test_run10.npy
#       fish11_final_predictions_reservoir_test_run10.npy
#     seq_15/
#       fish11_final_predictions_bert_test_run10.npy
#       fish11_final_predictions_deepseek_moe_test_run10.npy
#       fish11_final_predictions_gpt2_pretrained_test_run10.npy
#       fish11_final_predictions_lstm_test_run10.npy
#       fish11_final_predictions_reservoir_test_run10.npy
#     seq_20/
#       fish11_final_predictions_bert_test_run10.npy
#       fish11_final_predictions_deepseek_moe_test_run10.npy
#       fish11_final_predictions_gpt2_pretrained_test_run10.npy
#       fish11_final_predictions_lstm_test_run10.npy
#       fish11_final_predictions_reservoir_test_run10.npy
#     seq_5/
#       fish11_final_predictions_bert_test_run10.npy
#       fish11_final_predictions_deepseek_moe_test_run10.npy
#       fish11_final_predictions_gpt2_pretrained_test_run10.npy
#       fish11_final_predictions_lstm_test_run10.npy
#       fish11_final_predictions_reservoir_test_run10.npy
#   run_2/
#     seq_10/
#       fish11_final_predictions_bert_test_run2.npy
#       fish11_final_predictions_deepseek_moe_test_run2.npy
#       fish11_final_predictions_gpt2_pretrained_test_run2.npy
#       fish11_final_predictions_lstm_test_run2.npy
#       fish11_final_predictions_reservoir_test_run2.npy
#     seq_15/
#       fish11_final_predictions_bert_test_run2.npy
#       fish11_final_predictions_deepseek_moe_test_run2.npy
#       fish11_final_predictions_gpt2_pretrained_test_run2.npy
#       fish11_final_predictions_lstm_test_run2.npy
#       fish11_final_predictions_reservoir_test_run2.npy
#     seq_20/
#       fish11_final_predictions_bert_test_run2.npy
#       fish11_final_predictions_deepseek_moe_test_run2.npy
#       fish11_final_predictions_gpt2_pretrained_test_run2.npy
#       fish11_final_predictions_lstm_test_run2.npy
#       fish11_final_predictions_reservoir_test_run2.npy
#     seq_5/
#       fish11_final_predictions_bert_test_run2.npy
#       fish11_final_predictions_deepseek_moe_test_run2.npy
#       fish11_final_predictions_gpt2_pretrained_test_run2.npy
#       fish11_final_predictions_lstm_test_run2.npy
#       fish11_final_predictions_reservoir_test_run2.npy
#   run_3/
#     seq_10/
#       fish11_final_predictions_bert_test_run3.npy
#       fish11_final_predictions_deepseek_moe_test_run3.npy
#       fish11_final_predictions_gpt2_pretrained_test_run3.npy
#       fish11_final_predictions_lstm_test_run3.npy
#       fish11_final_predictions_reservoir_test_run3.npy
#     seq_15/
#       fish11_final_predictions_bert_test_run3.npy
#       fish11_final_predictions_deepseek_moe_test_run3.npy
#       fish11_final_predictions_gpt2_pretrained_test_run3.npy
#       fish11_final_predictions_lstm_test_run3.npy
#       fish11_final_predictions_reservoir_test_run3.npy
#     seq_20/
#       fish11_final_predictions_bert_test_run3.npy
#       fish11_final_predictions_deepseek_moe_test_run3.npy
#       fish11_final_predictions_gpt2_pretrained_test_run3.npy
#       fish11_final_predictions_lstm_test_run3.npy
#       fish11_final_predictions_reservoir_test_run3.npy
#     seq_5/
#       fish11_final_predictions_bert_test_run3.npy
#       fish11_final_predictions_deepseek_moe_test_run3.npy
#       fish11_final_predictions_gpt2_pretrained_test_run3.npy
#       fish11_final_predictions_lstm_test_run3.npy
#       fish11_final_predictions_reservoir_test_run3.npy
#   run_4/
#     seq_10/
#       fish11_final_predictions_bert_test_run4.npy
#       fish11_final_predictions_deepseek_moe_test_run4.npy
#       fish11_final_predictions_gpt2_pretrained_test_run4.npy
#       fish11_final_predictions_lstm_test_run4.npy
#       fish11_final_predictions_reservoir_test_run4.npy
#     seq_15/
#       fish11_final_predictions_bert_test_run4.npy
#       fish11_final_predictions_deepseek_moe_test_run4.npy
#       fish11_final_predictions_gpt2_pretrained_test_run4.npy
#       fish11_final_predictions_lstm_test_run4.npy
#       fish11_final_predictions_reservoir_test_run4.npy
#     seq_20/
#       fish11_final_predictions_bert_test_run4.npy
#       fish11_final_predictions_deepseek_moe_test_run4.npy
#       fish11_final_predictions_gpt2_pretrained_test_run4.npy
#       fish11_final_predictions_lstm_test_run4.npy
#       fish11_final_predictions_reservoir_test_run4.npy
#     seq_5/
#       fish11_final_predictions_bert_test_run4.npy
#       fish11_final_predictions_deepseek_moe_test_run4.npy
#       fish11_final_predictions_gpt2_pretrained_test_run4.npy
#       fish11_final_predictions_lstm_test_run4.npy
#       fish11_final_predictions_reservoir_test_run4.npy
#   run_5/
#     seq_10/
#       fish11_final_predictions_bert_test_run5.npy
#       fish11_final_predictions_deepseek_moe_test_run5.npy
#       fish11_final_predictions_gpt2_pretrained_test_run5.npy
#       fish11_final_predictions_lstm_test_run5.npy
#       fish11_final_predictions_reservoir_test_run5.npy
#     seq_15/
#       fish11_final_predictions_bert_test_run5.npy
#       fish11_final_predictions_deepseek_moe_test_run5.npy
#       fish11_final_predictions_gpt2_pretrained_test_run5.npy
#       fish11_final_predictions_lstm_test_run5.npy
#       fish11_final_predictions_reservoir_test_run5.npy
#     seq_20/
#       fish11_final_predictions_bert_test_run5.npy
#       fish11_final_predictions_deepseek_moe_test_run5.npy
#       fish11_final_predictions_gpt2_pretrained_test_run5.npy
#       fish11_final_predictions_lstm_test_run5.npy
#       fish11_final_predictions_reservoir_test_run5.npy
#     seq_5/
#       fish11_final_predictions_bert_test_run5.npy
#       fish11_final_predictions_deepseek_moe_test_run5.npy
#       fish11_final_predictions_gpt2_pretrained_test_run5.npy
#       fish11_final_predictions_lstm_test_run5.npy
#       fish11_final_predictions_reservoir_test_run5.npy
#   run_6/
#     seq_10/
#       fish11_final_predictions_bert_test_run6.npy
#       fish11_final_predictions_deepseek_moe_test_run6.npy
#       fish11_final_predictions_gpt2_pretrained_test_run6.npy
#       fish11_final_predictions_lstm_test_run6.npy
#       fish11_final_predictions_reservoir_test_run6.npy
#     seq_15/
#       fish11_final_predictions_bert_test_run6.npy
#       fish11_final_predictions_deepseek_moe_test_run6.npy
#       fish11_final_predictions_gpt2_pretrained_test_run6.npy
#       fish11_final_predictions_lstm_test_run6.npy
#       fish11_final_predictions_reservoir_test_run6.npy
#     seq_20/
#       fish11_final_predictions_bert_test_run6.npy
#       fish11_final_predictions_deepseek_moe_test_run6.npy
#       fish11_final_predictions_gpt2_pretrained_test_run6.npy
#       fish11_final_predictions_lstm_test_run6.npy
#       fish11_final_predictions_reservoir_test_run6.npy
#     seq_5/
#       fish11_final_predictions_bert_test_run6.npy
#       fish11_final_predictions_deepseek_moe_test_run6.npy
#       fish11_final_predictions_gpt2_pretrained_test_run6.npy
#       fish11_final_predictions_lstm_test_run6.npy
#       fish11_final_predictions_reservoir_test_run6.npy
#   run_7/
#     seq_10/
#       fish11_final_predictions_bert_test_run7.npy
#       fish11_final_predictions_deepseek_moe_test_run7.npy
#       fish11_final_predictions_gpt2_pretrained_test_run7.npy
#       fish11_final_predictions_lstm_test_run7.npy
#       fish11_final_predictions_reservoir_test_run7.npy
#     seq_15/
#       fish11_final_predictions_bert_test_run7.npy
#       fish11_final_predictions_deepseek_moe_test_run7.npy
#       fish11_final_predictions_gpt2_pretrained_test_run7.npy
#       fish11_final_predictions_lstm_test_run7.npy
#       fish11_final_predictions_reservoir_test_run7.npy
#     seq_20/
#       fish11_final_predictions_bert_test_run7.npy
#       fish11_final_predictions_deepseek_moe_test_run7.npy
#       fish11_final_predictions_gpt2_pretrained_test_run7.npy
#       fish11_final_predictions_lstm_test_run7.npy
#       fish11_final_predictions_reservoir_test_run7.npy
#     seq_5/
#       fish11_final_predictions_bert_test_run7.npy
#       fish11_final_predictions_deepseek_moe_test_run7.npy
#       fish11_final_predictions_gpt2_pretrained_test_run7.npy
#       fish11_final_predictions_lstm_test_run7.npy
#       fish11_final_predictions_reservoir_test_run7.npy
#   run_8/
#     seq_10/
#       fish11_final_predictions_bert_test_run8.npy
#       fish11_final_predictions_deepseek_moe_test_run8.npy
#       fish11_final_predictions_gpt2_pretrained_test_run8.npy
#       fish11_final_predictions_lstm_test_run8.npy
#       fish11_final_predictions_reservoir_test_run8.npy
#     seq_15/
#       fish11_final_predictions_bert_test_run8.npy
#       fish11_final_predictions_deepseek_moe_test_run8.npy
#       fish11_final_predictions_gpt2_pretrained_test_run8.npy
#       fish11_final_predictions_lstm_test_run8.npy
#       fish11_final_predictions_reservoir_test_run8.npy
#     seq_20/
#       fish11_final_predictions_bert_test_run8.npy
#       fish11_final_predictions_deepseek_moe_test_run8.npy
#       fish11_final_predictions_gpt2_pretrained_test_run8.npy
#       fish11_final_predictions_lstm_test_run8.npy
#       fish11_final_predictions_reservoir_test_run8.npy
#     seq_5/
#       fish11_final_predictions_bert_test_run8.npy
#       fish11_final_predictions_deepseek_moe_test_run8.npy
#       fish11_final_predictions_gpt2_pretrained_test_run8.npy
#       fish11_final_predictions_lstm_test_run8.npy
#       fish11_final_predictions_reservoir_test_run8.npy
#   run_9/
#     seq_10/
#       fish11_final_predictions_bert_test_run9.npy
#       fish11_final_predictions_deepseek_moe_test_run9.npy
#       fish11_final_predictions_gpt2_pretrained_test_run9.npy
#       fish11_final_predictions_lstm_test_run9.npy
#       fish11_final_predictions_reservoir_test_run9.npy
#     seq_15/
#       fish11_final_predictions_bert_test_run9.npy
#       fish11_final_predictions_deepseek_moe_test_run9.npy
#       fish11_final_predictions_gpt2_pretrained_test_run9.npy
#       fish11_final_predictions_lstm_test_run9.npy
#       fish11_final_predictions_reservoir_test_run9.npy
#     seq_20/
#       fish11_final_predictions_bert_test_run9.npy
#       fish11_final_predictions_deepseek_moe_test_run9.npy
#       fish11_final_predictions_gpt2_pretrained_test_run9.npy
#       fish11_final_predictions_lstm_test_run9.npy
#       fish11_final_predictions_reservoir_test_run9.npy
#     seq_5/
#       fish11_final_predictions_bert_test_run9.npy
#       fish11_final_predictions_deepseek_moe_test_run9.npy
#       fish11_final_predictions_gpt2_pretrained_test_run9.npy
#       fish11_final_predictions_lstm_test_run9.npy
#       fish11_final_predictions_reservoir_test_run9.npy
# fish12/
#   fish12_final_predictions_groundtruth_test.npy
#   fish12_final_predictions_groundtruth_val.npy
#   fish12_grouped_rmse_comparison.png
#   run_1/
#     seq_10/
#       fish12_final_predictions_bert_test_run1.npy
#       fish12_final_predictions_deepseek_moe_test_run1.npy
#       fish12_final_predictions_gpt2_pretrained_test_run1.npy
#       fish12_final_predictions_lstm_test_run1.npy
#       fish12_final_predictions_reservoir_test_run1.npy
#     seq_15/
#       fish12_final_predictions_bert_test_run1.npy
#       fish12_final_predictions_deepseek_moe_test_run1.npy
#       fish12_final_predictions_gpt2_pretrained_test_run1.npy
#       fish12_final_predictions_lstm_test_run1.npy
#       fish12_final_predictions_reservoir_test_run1.npy
#     seq_20/
#       fish12_final_predictions_bert_test_run1.npy
#       fish12_final_predictions_deepseek_moe_test_run1.npy
#       fish12_final_predictions_gpt2_pretrained_test_run1.npy
#       fish12_final_predictions_lstm_test_run1.npy
#       fish12_final_predictions_reservoir_test_run1.npy
#     seq_5/
#       fish12_final_predictions_bert_test_run1.npy
#       fish12_final_predictions_deepseek_moe_test_run1.npy
#       fish12_final_predictions_gpt2_pretrained_test_run1.npy
#       fish12_final_predictions_lstm_test_run1.npy
#       fish12_final_predictions_reservoir_test_run1.npy
#   run_10/
#     seq_10/
#       fish12_final_predictions_bert_test_run10.npy
#       fish12_final_predictions_deepseek_moe_test_run10.npy
#       fish12_final_predictions_gpt2_pretrained_test_run10.npy
#       fish12_final_predictions_lstm_test_run10.npy
#       fish12_final_predictions_reservoir_test_run10.npy
#     seq_15/
#       fish12_final_predictions_bert_test_run10.npy
#       fish12_final_predictions_deepseek_moe_test_run10.npy
#       fish12_final_predictions_gpt2_pretrained_test_run10.npy
#       fish12_final_predictions_lstm_test_run10.npy
#       fish12_final_predictions_reservoir_test_run10.npy
#     seq_20/
#       fish12_final_predictions_bert_test_run10.npy
#       fish12_final_predictions_deepseek_moe_test_run10.npy
#       fish12_final_predictions_gpt2_pretrained_test_run10.npy
#       fish12_final_predictions_lstm_test_run10.npy
#       fish12_final_predictions_reservoir_test_run10.npy
#     seq_5/
#       fish12_final_predictions_bert_test_run10.npy
#       fish12_final_predictions_deepseek_moe_test_run10.npy
#       fish12_final_predictions_gpt2_pretrained_test_run10.npy
#       fish12_final_predictions_lstm_test_run10.npy
#       fish12_final_predictions_reservoir_test_run10.npy
#   run_2/
#     seq_10/
#       fish12_final_predictions_bert_test_run2.npy
#       fish12_final_predictions_deepseek_moe_test_run2.npy
#       fish12_final_predictions_gpt2_pretrained_test_run2.npy
#       fish12_final_predictions_lstm_test_run2.npy
#       fish12_final_predictions_reservoir_test_run2.npy
#     seq_15/
#       fish12_final_predictions_bert_test_run2.npy
#       fish12_final_predictions_deepseek_moe_test_run2.npy
#       fish12_final_predictions_gpt2_pretrained_test_run2.npy
#       fish12_final_predictions_lstm_test_run2.npy
#       fish12_final_predictions_reservoir_test_run2.npy
#     seq_20/
#       fish12_final_predictions_bert_test_run2.npy
#       fish12_final_predictions_deepseek_moe_test_run2.npy
#       fish12_final_predictions_gpt2_pretrained_test_run2.npy
#       fish12_final_predictions_lstm_test_run2.npy
#       fish12_final_predictions_reservoir_test_run2.npy
#     seq_5/
#       fish12_final_predictions_bert_test_run2.npy
#       fish12_final_predictions_deepseek_moe_test_run2.npy
#       fish12_final_predictions_gpt2_pretrained_test_run2.npy
#       fish12_final_predictions_lstm_test_run2.npy
#       fish12_final_predictions_reservoir_test_run2.npy
#   run_3/
#     seq_10/
#       fish12_final_predictions_bert_test_run3.npy
#       fish12_final_predictions_deepseek_moe_test_run3.npy
#       fish12_final_predictions_gpt2_pretrained_test_run3.npy
#       fish12_final_predictions_lstm_test_run3.npy
#       fish12_final_predictions_reservoir_test_run3.npy
#     seq_15/
#       fish12_final_predictions_bert_test_run3.npy
#       fish12_final_predictions_deepseek_moe_test_run3.npy
#       fish12_final_predictions_gpt2_pretrained_test_run3.npy
#       fish12_final_predictions_lstm_test_run3.npy
#       fish12_final_predictions_reservoir_test_run3.npy
#     seq_20/
#       fish12_final_predictions_bert_test_run3.npy
#       fish12_final_predictions_deepseek_moe_test_run3.npy
#       fish12_final_predictions_gpt2_pretrained_test_run3.npy
#       fish12_final_predictions_lstm_test_run3.npy
#       fish12_final_predictions_reservoir_test_run3.npy
#     seq_5/
#       fish12_final_predictions_bert_test_run3.npy
#       fish12_final_predictions_deepseek_moe_test_run3.npy
#       fish12_final_predictions_gpt2_pretrained_test_run3.npy
#       fish12_final_predictions_lstm_test_run3.npy
#       fish12_final_predictions_reservoir_test_run3.npy
#   run_4/
#     seq_10/
#       fish12_final_predictions_bert_test_run4.npy
#       fish12_final_predictions_deepseek_moe_test_run4.npy
#       fish12_final_predictions_gpt2_pretrained_test_run4.npy
#       fish12_final_predictions_lstm_test_run4.npy
#       fish12_final_predictions_reservoir_test_run4.npy
#     seq_15/
#       fish12_final_predictions_bert_test_run4.npy
#       fish12_final_predictions_deepseek_moe_test_run4.npy
#       fish12_final_predictions_gpt2_pretrained_test_run4.npy
#       fish12_final_predictions_lstm_test_run4.npy
#       fish12_final_predictions_reservoir_test_run4.npy
#     seq_20/
#       fish12_final_predictions_bert_test_run4.npy
#       fish12_final_predictions_deepseek_moe_test_run4.npy
#       fish12_final_predictions_gpt2_pretrained_test_run4.npy
#       fish12_final_predictions_lstm_test_run4.npy
#       fish12_final_predictions_reservoir_test_run4.npy
#     seq_5/
#       fish12_final_predictions_bert_test_run4.npy
#       fish12_final_predictions_deepseek_moe_test_run4.npy
#       fish12_final_predictions_gpt2_pretrained_test_run4.npy
#       fish12_final_predictions_lstm_test_run4.npy
#       fish12_final_predictions_reservoir_test_run4.npy
#   run_5/
#     seq_10/
#       fish12_final_predictions_bert_test_run5.npy
#       fish12_final_predictions_deepseek_moe_test_run5.npy
#       fish12_final_predictions_gpt2_pretrained_test_run5.npy
#       fish12_final_predictions_lstm_test_run5.npy
#       fish12_final_predictions_reservoir_test_run5.npy
#     seq_15/
#       fish12_final_predictions_bert_test_run5.npy
#       fish12_final_predictions_deepseek_moe_test_run5.npy
#       fish12_final_predictions_gpt2_pretrained_test_run5.npy
#       fish12_final_predictions_lstm_test_run5.npy
#       fish12_final_predictions_reservoir_test_run5.npy
#     seq_20/
#       fish12_final_predictions_bert_test_run5.npy
#       fish12_final_predictions_deepseek_moe_test_run5.npy
#       fish12_final_predictions_gpt2_pretrained_test_run5.npy
#       fish12_final_predictions_lstm_test_run5.npy
#       fish12_final_predictions_reservoir_test_run5.npy
#     seq_5/
#       fish12_final_predictions_bert_test_run5.npy
#       fish12_final_predictions_deepseek_moe_test_run5.npy
#       fish12_final_predictions_gpt2_pretrained_test_run5.npy
#       fish12_final_predictions_lstm_test_run5.npy
#       fish12_final_predictions_reservoir_test_run5.npy
#   run_6/
#     seq_10/
#       fish12_final_predictions_bert_test_run6.npy
#       fish12_final_predictions_deepseek_moe_test_run6.npy
#       fish12_final_predictions_gpt2_pretrained_test_run6.npy
#       fish12_final_predictions_lstm_test_run6.npy
#       fish12_final_predictions_reservoir_test_run6.npy
#     seq_15/
#       fish12_final_predictions_bert_test_run6.npy
#       fish12_final_predictions_deepseek_moe_test_run6.npy
#       fish12_final_predictions_gpt2_pretrained_test_run6.npy
#       fish12_final_predictions_lstm_test_run6.npy
#       fish12_final_predictions_reservoir_test_run6.npy
#     seq_20/
#       fish12_final_predictions_bert_test_run6.npy
#       fish12_final_predictions_deepseek_moe_test_run6.npy
#       fish12_final_predictions_gpt2_pretrained_test_run6.npy
#       fish12_final_predictions_lstm_test_run6.npy
#       fish12_final_predictions_reservoir_test_run6.npy
#     seq_5/
#       fish12_final_predictions_bert_test_run6.npy
#       fish12_final_predictions_deepseek_moe_test_run6.npy
#       fish12_final_predictions_gpt2_pretrained_test_run6.npy
#       fish12_final_predictions_lstm_test_run6.npy
#       fish12_final_predictions_reservoir_test_run6.npy
#   run_7/
#     seq_10/
#       fish12_final_predictions_bert_test_run7.npy
#       fish12_final_predictions_deepseek_moe_test_run7.npy
#       fish12_final_predictions_gpt2_pretrained_test_run7.npy
#       fish12_final_predictions_lstm_test_run7.npy
#       fish12_final_predictions_reservoir_test_run7.npy
#     seq_15/
#       fish12_final_predictions_bert_test_run7.npy
#       fish12_final_predictions_deepseek_moe_test_run7.npy
#       fish12_final_predictions_gpt2_pretrained_test_run7.npy
#       fish12_final_predictions_lstm_test_run7.npy
#       fish12_final_predictions_reservoir_test_run7.npy
#     seq_20/
#       fish12_final_predictions_bert_test_run7.npy
#       fish12_final_predictions_deepseek_moe_test_run7.npy
#       fish12_final_predictions_gpt2_pretrained_test_run7.npy
#       fish12_final_predictions_lstm_test_run7.npy
#       fish12_final_predictions_reservoir_test_run7.npy
#     seq_5/
#       fish12_final_predictions_bert_test_run7.npy
#       fish12_final_predictions_deepseek_moe_test_run7.npy
#       fish12_final_predictions_gpt2_pretrained_test_run7.npy
#       fish12_final_predictions_lstm_test_run7.npy
#       fish12_final_predictions_reservoir_test_run7.npy
#   run_8/
#     seq_10/
#       fish12_final_predictions_bert_test_run8.npy
#       fish12_final_predictions_deepseek_moe_test_run8.npy
#       fish12_final_predictions_gpt2_pretrained_test_run8.npy
#       fish12_final_predictions_lstm_test_run8.npy
#       fish12_final_predictions_reservoir_test_run8.npy
#     seq_15/
#       fish12_final_predictions_bert_test_run8.npy
#       fish12_final_predictions_deepseek_moe_test_run8.npy
#       fish12_final_predictions_gpt2_pretrained_test_run8.npy
#       fish12_final_predictions_lstm_test_run8.npy
#       fish12_final_predictions_reservoir_test_run8.npy
#     seq_20/
#       fish12_final_predictions_bert_test_run8.npy
#       fish12_final_predictions_deepseek_moe_test_run8.npy
#       fish12_final_predictions_gpt2_pretrained_test_run8.npy
#       fish12_final_predictions_lstm_test_run8.npy
#       fish12_final_predictions_reservoir_test_run8.npy
#     seq_5/
#       fish12_final_predictions_bert_test_run8.npy
#       fish12_final_predictions_deepseek_moe_test_run8.npy
#       fish12_final_predictions_gpt2_pretrained_test_run8.npy
#       fish12_final_predictions_lstm_test_run8.npy
#       fish12_final_predictions_reservoir_test_run8.npy
#   run_9/
#     seq_10/
#       fish12_final_predictions_bert_test_run9.npy
#       fish12_final_predictions_deepseek_moe_test_run9.npy
#       fish12_final_predictions_gpt2_pretrained_test_run9.npy
#       fish12_final_predictions_lstm_test_run9.npy
#       fish12_final_predictions_reservoir_test_run9.npy
#     seq_15/
#       fish12_final_predictions_bert_test_run9.npy
#       fish12_final_predictions_deepseek_moe_test_run9.npy
#       fish12_final_predictions_gpt2_pretrained_test_run9.npy
#       fish12_final_predictions_lstm_test_run9.npy
#       fish12_final_predictions_reservoir_test_run9.npy
#     seq_20/
#       fish12_final_predictions_bert_test_run9.npy
#       fish12_final_predictions_deepseek_moe_test_run9.npy
#       fish12_final_predictions_gpt2_pretrained_test_run9.npy
#       fish12_final_predictions_lstm_test_run9.npy
#       fish12_final_predictions_reservoir_test_run9.npy
#     seq_5/
#       fish12_final_predictions_bert_test_run9.npy
#       fish12_final_predictions_deepseek_moe_test_run9.npy
#       fish12_final_predictions_gpt2_pretrained_test_run9.npy
#       fish12_final_predictions_lstm_test_run9.npy
#       fish12_final_predictions_reservoir_test_run9.npy
# fish13/
#   fish13_final_predictions_groundtruth_test.npy
#   fish13_final_predictions_groundtruth_val.npy
#   fish13_grouped_rmse_comparison.png
#   run_1/
#     seq_10/
#       fish13_final_predictions_bert_test_run1.npy
#       fish13_final_predictions_deepseek_moe_test_run1.npy
#       fish13_final_predictions_gpt2_pretrained_test_run1.npy
#       fish13_final_predictions_lstm_test_run1.npy
#       fish13_final_predictions_reservoir_test_run1.npy
#     seq_15/
#       fish13_final_predictions_bert_test_run1.npy
#       fish13_final_predictions_deepseek_moe_test_run1.npy
#       fish13_final_predictions_gpt2_pretrained_test_run1.npy
#       fish13_final_predictions_lstm_test_run1.npy
#       fish13_final_predictions_reservoir_test_run1.npy
#     seq_20/
#       fish13_final_predictions_bert_test_run1.npy
#       fish13_final_predictions_deepseek_moe_test_run1.npy
#       fish13_final_predictions_gpt2_pretrained_test_run1.npy
#       fish13_final_predictions_lstm_test_run1.npy
#       fish13_final_predictions_reservoir_test_run1.npy
#     seq_5/
#       fish13_final_predictions_bert_test_run1.npy
#       fish13_final_predictions_deepseek_moe_test_run1.npy
#       fish13_final_predictions_gpt2_pretrained_test_run1.npy
#       fish13_final_predictions_lstm_test_run1.npy
#       fish13_final_predictions_reservoir_test_run1.npy
#   run_10/
#     seq_10/
#       fish13_final_predictions_bert_test_run10.npy
#       fish13_final_predictions_deepseek_moe_test_run10.npy
#       fish13_final_predictions_gpt2_pretrained_test_run10.npy
#       fish13_final_predictions_lstm_test_run10.npy
#       fish13_final_predictions_reservoir_test_run10.npy
#     seq_15/
#       fish13_final_predictions_bert_test_run10.npy
#       fish13_final_predictions_deepseek_moe_test_run10.npy
#       fish13_final_predictions_gpt2_pretrained_test_run10.npy
#       fish13_final_predictions_lstm_test_run10.npy
#       fish13_final_predictions_reservoir_test_run10.npy
#     seq_20/
#       fish13_final_predictions_bert_test_run10.npy
#       fish13_final_predictions_deepseek_moe_test_run10.npy
#       fish13_final_predictions_gpt2_pretrained_test_run10.npy
#       fish13_final_predictions_lstm_test_run10.npy
#       fish13_final_predictions_reservoir_test_run10.npy
#     seq_5/
#       fish13_final_predictions_bert_test_run10.npy
#       fish13_final_predictions_deepseek_moe_test_run10.npy
#       fish13_final_predictions_gpt2_pretrained_test_run10.npy
#       fish13_final_predictions_lstm_test_run10.npy
#       fish13_final_predictions_reservoir_test_run10.npy
#   run_2/
#     seq_10/
#       fish13_final_predictions_bert_test_run2.npy
#       fish13_final_predictions_deepseek_moe_test_run2.npy
#       fish13_final_predictions_gpt2_pretrained_test_run2.npy
#       fish13_final_predictions_lstm_test_run2.npy
#       fish13_final_predictions_reservoir_test_run2.npy
#     seq_15/
#       fish13_final_predictions_bert_test_run2.npy
#       fish13_final_predictions_deepseek_moe_test_run2.npy
#       fish13_final_predictions_gpt2_pretrained_test_run2.npy
#       fish13_final_predictions_lstm_test_run2.npy
#       fish13_final_predictions_reservoir_test_run2.npy
#     seq_20/
#       fish13_final_predictions_bert_test_run2.npy
#       fish13_final_predictions_deepseek_moe_test_run2.npy
#       fish13_final_predictions_gpt2_pretrained_test_run2.npy
#       fish13_final_predictions_lstm_test_run2.npy
#       fish13_final_predictions_reservoir_test_run2.npy
#     seq_5/
#       fish13_final_predictions_bert_test_run2.npy
#       fish13_final_predictions_deepseek_moe_test_run2.npy
#       fish13_final_predictions_gpt2_pretrained_test_run2.npy
#       fish13_final_predictions_lstm_test_run2.npy
#       fish13_final_predictions_reservoir_test_run2.npy
#   run_3/
#     seq_10/
#       fish13_final_predictions_bert_test_run3.npy
#       fish13_final_predictions_deepseek_moe_test_run3.npy
#       fish13_final_predictions_gpt2_pretrained_test_run3.npy
#       fish13_final_predictions_lstm_test_run3.npy
#       fish13_final_predictions_reservoir_test_run3.npy
#     seq_15/
#       fish13_final_predictions_bert_test_run3.npy
#       fish13_final_predictions_deepseek_moe_test_run3.npy
#       fish13_final_predictions_gpt2_pretrained_test_run3.npy
#       fish13_final_predictions_lstm_test_run3.npy
#       fish13_final_predictions_reservoir_test_run3.npy
#     seq_20/
#       fish13_final_predictions_bert_test_run3.npy
#       fish13_final_predictions_deepseek_moe_test_run3.npy
#       fish13_final_predictions_gpt2_pretrained_test_run3.npy
#       fish13_final_predictions_lstm_test_run3.npy
#       fish13_final_predictions_reservoir_test_run3.npy
#     seq_5/
#       fish13_final_predictions_bert_test_run3.npy
#       fish13_final_predictions_deepseek_moe_test_run3.npy
#       fish13_final_predictions_gpt2_pretrained_test_run3.npy
#       fish13_final_predictions_lstm_test_run3.npy
#       fish13_final_predictions_reservoir_test_run3.npy
#   run_4/
#     seq_10/
#       fish13_final_predictions_bert_test_run4.npy
#       fish13_final_predictions_deepseek_moe_test_run4.npy
#       fish13_final_predictions_gpt2_pretrained_test_run4.npy
#       fish13_final_predictions_lstm_test_run4.npy
#       fish13_final_predictions_reservoir_test_run4.npy
#     seq_15/
#       fish13_final_predictions_bert_test_run4.npy
#       fish13_final_predictions_deepseek_moe_test_run4.npy
#       fish13_final_predictions_gpt2_pretrained_test_run4.npy
#       fish13_final_predictions_lstm_test_run4.npy
#       fish13_final_predictions_reservoir_test_run4.npy
#     seq_20/
#       fish13_final_predictions_bert_test_run4.npy
#       fish13_final_predictions_deepseek_moe_test_run4.npy
#       fish13_final_predictions_gpt2_pretrained_test_run4.npy
#       fish13_final_predictions_lstm_test_run4.npy
#       fish13_final_predictions_reservoir_test_run4.npy
#     seq_5/
#       fish13_final_predictions_bert_test_run4.npy
#       fish13_final_predictions_deepseek_moe_test_run4.npy
#       fish13_final_predictions_gpt2_pretrained_test_run4.npy
#       fish13_final_predictions_lstm_test_run4.npy
#       fish13_final_predictions_reservoir_test_run4.npy
#   run_5/
#     seq_10/
#       fish13_final_predictions_bert_test_run5.npy
#       fish13_final_predictions_deepseek_moe_test_run5.npy
#       fish13_final_predictions_gpt2_pretrained_test_run5.npy
#       fish13_final_predictions_lstm_test_run5.npy
#       fish13_final_predictions_reservoir_test_run5.npy
#     seq_15/
#       fish13_final_predictions_bert_test_run5.npy
#       fish13_final_predictions_deepseek_moe_test_run5.npy
#       fish13_final_predictions_gpt2_pretrained_test_run5.npy
#       fish13_final_predictions_lstm_test_run5.npy
#       fish13_final_predictions_reservoir_test_run5.npy
#     seq_20/
#       fish13_final_predictions_bert_test_run5.npy
#       fish13_final_predictions_deepseek_moe_test_run5.npy
#       fish13_final_predictions_gpt2_pretrained_test_run5.npy
#       fish13_final_predictions_lstm_test_run5.npy
#       fish13_final_predictions_reservoir_test_run5.npy
#     seq_5/
#       fish13_final_predictions_bert_test_run5.npy
#       fish13_final_predictions_deepseek_moe_test_run5.npy
#       fish13_final_predictions_gpt2_pretrained_test_run5.npy
#       fish13_final_predictions_lstm_test_run5.npy
#       fish13_final_predictions_reservoir_test_run5.npy
#   run_6/
#     seq_10/
#       fish13_final_predictions_bert_test_run6.npy
#       fish13_final_predictions_deepseek_moe_test_run6.npy
#       fish13_final_predictions_gpt2_pretrained_test_run6.npy
#       fish13_final_predictions_lstm_test_run6.npy
#       fish13_final_predictions_reservoir_test_run6.npy
#     seq_15/
#       fish13_final_predictions_bert_test_run6.npy
#       fish13_final_predictions_deepseek_moe_test_run6.npy
#       fish13_final_predictions_gpt2_pretrained_test_run6.npy
#       fish13_final_predictions_lstm_test_run6.npy
#       fish13_final_predictions_reservoir_test_run6.npy
#     seq_20/
#       fish13_final_predictions_bert_test_run6.npy
#       fish13_final_predictions_deepseek_moe_test_run6.npy
#       fish13_final_predictions_gpt2_pretrained_test_run6.npy
#       fish13_final_predictions_lstm_test_run6.npy
#       fish13_final_predictions_reservoir_test_run6.npy
#     seq_5/
#       fish13_final_predictions_bert_test_run6.npy
#       fish13_final_predictions_deepseek_moe_test_run6.npy
#       fish13_final_predictions_gpt2_pretrained_test_run6.npy
#       fish13_final_predictions_lstm_test_run6.npy
#       fish13_final_predictions_reservoir_test_run6.npy
#   run_7/
#     seq_10/
#       fish13_final_predictions_bert_test_run7.npy
#       fish13_final_predictions_deepseek_moe_test_run7.npy
#       fish13_final_predictions_gpt2_pretrained_test_run7.npy
#       fish13_final_predictions_lstm_test_run7.npy
#       fish13_final_predictions_reservoir_test_run7.npy
#     seq_15/
#       fish13_final_predictions_bert_test_run7.npy
#       fish13_final_predictions_deepseek_moe_test_run7.npy
#       fish13_final_predictions_gpt2_pretrained_test_run7.npy
#       fish13_final_predictions_lstm_test_run7.npy
#       fish13_final_predictions_reservoir_test_run7.npy
#     seq_20/
#       fish13_final_predictions_bert_test_run7.npy
#       fish13_final_predictions_deepseek_moe_test_run7.npy
#       fish13_final_predictions_gpt2_pretrained_test_run7.npy
#       fish13_final_predictions_lstm_test_run7.npy
#       fish13_final_predictions_reservoir_test_run7.npy
#     seq_5/
#       fish13_final_predictions_bert_test_run7.npy
#       fish13_final_predictions_deepseek_moe_test_run7.npy
#       fish13_final_predictions_gpt2_pretrained_test_run7.npy
#       fish13_final_predictions_lstm_test_run7.npy
#       fish13_final_predictions_reservoir_test_run7.npy
#   run_8/
#     seq_10/
#       fish13_final_predictions_bert_test_run8.npy
#       fish13_final_predictions_deepseek_moe_test_run8.npy
#       fish13_final_predictions_gpt2_pretrained_test_run8.npy
#       fish13_final_predictions_lstm_test_run8.npy
#       fish13_final_predictions_reservoir_test_run8.npy
#     seq_15/
#       fish13_final_predictions_bert_test_run8.npy
#       fish13_final_predictions_deepseek_moe_test_run8.npy
#       fish13_final_predictions_gpt2_pretrained_test_run8.npy
#       fish13_final_predictions_lstm_test_run8.npy
#       fish13_final_predictions_reservoir_test_run8.npy
#     seq_20/
#       fish13_final_predictions_bert_test_run8.npy
#       fish13_final_predictions_deepseek_moe_test_run8.npy
#       fish13_final_predictions_gpt2_pretrained_test_run8.npy
#       fish13_final_predictions_lstm_test_run8.npy
#       fish13_final_predictions_reservoir_test_run8.npy
#     seq_5/
#       fish13_final_predictions_bert_test_run8.npy
#       fish13_final_predictions_deepseek_moe_test_run8.npy
#       fish13_final_predictions_gpt2_pretrained_test_run8.npy
#       fish13_final_predictions_lstm_test_run8.npy
#       fish13_final_predictions_reservoir_test_run8.npy
#   run_9/
#     seq_10/
#       fish13_final_predictions_bert_test_run9.npy
#       fish13_final_predictions_deepseek_moe_test_run9.npy
#       fish13_final_predictions_gpt2_pretrained_test_run9.npy
#       fish13_final_predictions_lstm_test_run9.npy
#       fish13_final_predictions_reservoir_test_run9.npy
#     seq_15/
#       fish13_final_predictions_bert_test_run9.npy
#       fish13_final_predictions_deepseek_moe_test_run9.npy
#       fish13_final_predictions_gpt2_pretrained_test_run9.npy
#       fish13_final_predictions_lstm_test_run9.npy
#       fish13_final_predictions_reservoir_test_run9.npy
#     seq_20/
#       fish13_final_predictions_bert_test_run9.npy
#       fish13_final_predictions_deepseek_moe_test_run9.npy
#       fish13_final_predictions_gpt2_pretrained_test_run9.npy
#       fish13_final_predictions_lstm_test_run9.npy
#       fish13_final_predictions_reservoir_test_run9.npy
#     seq_5/
#       fish13_final_predictions_bert_test_run9.npy
#       fish13_final_predictions_deepseek_moe_test_run9.npy
#       fish13_final_predictions_gpt2_pretrained_test_run9.npy
#       fish13_final_predictions_lstm_test_run9.npy
#       fish13_final_predictions_reservoir_test_run9.npy
# fish9/
#   fish9_final_predictions_groundtruth_test.npy
#   fish9_final_predictions_groundtruth_val.npy
#   fish9_grouped_rmse_comparison.png
#   run_1/
#     seq_10/
#       fish9_final_predictions_bert_test_run1.npy
#       fish9_final_predictions_deepseek_moe_test_run1.npy
#       fish9_final_predictions_gpt2_pretrained_test_run1.npy
#       fish9_final_predictions_lstm_test_run1.npy
#       fish9_final_predictions_reservoir_test_run1.npy
#     seq_15/
#       fish9_final_predictions_bert_test_run1.npy
#       fish9_final_predictions_deepseek_moe_test_run1.npy
#       fish9_final_predictions_gpt2_pretrained_test_run1.npy
#       fish9_final_predictions_lstm_test_run1.npy
#       fish9_final_predictions_reservoir_test_run1.npy
#     seq_20/
#       fish9_final_predictions_bert_test_run1.npy
#       fish9_final_predictions_deepseek_moe_test_run1.npy
#       fish9_final_predictions_gpt2_pretrained_test_run1.npy
#       fish9_final_predictions_lstm_test_run1.npy
#       fish9_final_predictions_reservoir_test_run1.npy
#     seq_5/
#       fish9_final_predictions_bert_test_run1.npy
#       fish9_final_predictions_deepseek_moe_test_run1.npy
#       fish9_final_predictions_gpt2_pretrained_test_run1.npy
#       fish9_final_predictions_lstm_test_run1.npy
#       fish9_final_predictions_reservoir_test_run1.npy
#   run_10/
#     seq_10/
#       fish9_final_predictions_bert_test_run10.npy
#       fish9_final_predictions_deepseek_moe_test_run10.npy
#       fish9_final_predictions_gpt2_pretrained_test_run10.npy
#       fish9_final_predictions_lstm_test_run10.npy
#       fish9_final_predictions_reservoir_test_run10.npy
#     seq_15/
#       fish9_final_predictions_bert_test_run10.npy
#       fish9_final_predictions_deepseek_moe_test_run10.npy
#       fish9_final_predictions_gpt2_pretrained_test_run10.npy
#       fish9_final_predictions_lstm_test_run10.npy
#       fish9_final_predictions_reservoir_test_run10.npy
#     seq_20/
#       fish9_final_predictions_bert_test_run10.npy
#       fish9_final_predictions_deepseek_moe_test_run10.npy
#       fish9_final_predictions_gpt2_pretrained_test_run10.npy
#       fish9_final_predictions_lstm_test_run10.npy
#       fish9_final_predictions_reservoir_test_run10.npy
#     seq_5/
#       fish9_final_predictions_bert_test_run10.npy
#       fish9_final_predictions_deepseek_moe_test_run10.npy
#       fish9_final_predictions_gpt2_pretrained_test_run10.npy
#       fish9_final_predictions_lstm_test_run10.npy
#       fish9_final_predictions_reservoir_test_run10.npy
#   run_2/
#     seq_10/
#       fish9_final_predictions_bert_test_run2.npy
#       fish9_final_predictions_deepseek_moe_test_run2.npy
#       fish9_final_predictions_gpt2_pretrained_test_run2.npy
#       fish9_final_predictions_lstm_test_run2.npy
#       fish9_final_predictions_reservoir_test_run2.npy
#     seq_15/
#       fish9_final_predictions_bert_test_run2.npy
#       fish9_final_predictions_deepseek_moe_test_run2.npy
#       fish9_final_predictions_gpt2_pretrained_test_run2.npy
#       fish9_final_predictions_lstm_test_run2.npy
#       fish9_final_predictions_reservoir_test_run2.npy
#     seq_20/
#       fish9_final_predictions_bert_test_run2.npy
#       fish9_final_predictions_deepseek_moe_test_run2.npy
#       fish9_final_predictions_gpt2_pretrained_test_run2.npy
#       fish9_final_predictions_lstm_test_run2.npy
#       fish9_final_predictions_reservoir_test_run2.npy
#     seq_5/
#       fish9_final_predictions_bert_test_run2.npy
#       fish9_final_predictions_deepseek_moe_test_run2.npy
#       fish9_final_predictions_gpt2_pretrained_test_run2.npy
#       fish9_final_predictions_lstm_test_run2.npy
#       fish9_final_predictions_reservoir_test_run2.npy
#   run_3/
#     seq_10/
#       fish9_final_predictions_bert_test_run3.npy
#       fish9_final_predictions_deepseek_moe_test_run3.npy
#       fish9_final_predictions_gpt2_pretrained_test_run3.npy
#       fish9_final_predictions_lstm_test_run3.npy
#       fish9_final_predictions_reservoir_test_run3.npy
#     seq_15/
#       fish9_final_predictions_bert_test_run3.npy
#       fish9_final_predictions_deepseek_moe_test_run3.npy
#       fish9_final_predictions_gpt2_pretrained_test_run3.npy
#       fish9_final_predictions_lstm_test_run3.npy
#       fish9_final_predictions_reservoir_test_run3.npy
#     seq_20/
#       fish9_final_predictions_bert_test_run3.npy
#       fish9_final_predictions_deepseek_moe_test_run3.npy
#       fish9_final_predictions_gpt2_pretrained_test_run3.npy
#       fish9_final_predictions_lstm_test_run3.npy
#       fish9_final_predictions_reservoir_test_run3.npy
#     seq_5/
#       fish9_final_predictions_bert_test_run3.npy
#       fish9_final_predictions_deepseek_moe_test_run3.npy
#       fish9_final_predictions_gpt2_pretrained_test_run3.npy
#       fish9_final_predictions_lstm_test_run3.npy
#       fish9_final_predictions_reservoir_test_run3.npy
#   run_4/
#     seq_10/
#       fish9_final_predictions_bert_test_run4.npy
#       fish9_final_predictions_deepseek_moe_test_run4.npy
#       fish9_final_predictions_gpt2_pretrained_test_run4.npy
#       fish9_final_predictions_lstm_test_run4.npy
#       fish9_final_predictions_reservoir_test_run4.npy
#     seq_15/
#       fish9_final_predictions_bert_test_run4.npy
#       fish9_final_predictions_deepseek_moe_test_run4.npy
#       fish9_final_predictions_gpt2_pretrained_test_run4.npy
#       fish9_final_predictions_lstm_test_run4.npy
#       fish9_final_predictions_reservoir_test_run4.npy
#     seq_20/
#       fish9_final_predictions_bert_test_run4.npy
#       fish9_final_predictions_deepseek_moe_test_run4.npy
#       fish9_final_predictions_gpt2_pretrained_test_run4.npy
#       fish9_final_predictions_lstm_test_run4.npy
#       fish9_final_predictions_reservoir_test_run4.npy
#     seq_5/
#       fish9_final_predictions_bert_test_run4.npy
#       fish9_final_predictions_deepseek_moe_test_run4.npy
#       fish9_final_predictions_gpt2_pretrained_test_run4.npy
#       fish9_final_predictions_lstm_test_run4.npy
#       fish9_final_predictions_reservoir_test_run4.npy
#   run_5/
#     seq_10/
#       fish9_final_predictions_bert_test_run5.npy
#       fish9_final_predictions_deepseek_moe_test_run5.npy
#       fish9_final_predictions_gpt2_pretrained_test_run5.npy
#       fish9_final_predictions_lstm_test_run5.npy
#       fish9_final_predictions_reservoir_test_run5.npy
#     seq_15/
#       fish9_final_predictions_bert_test_run5.npy
#       fish9_final_predictions_deepseek_moe_test_run5.npy
#       fish9_final_predictions_gpt2_pretrained_test_run5.npy
#       fish9_final_predictions_lstm_test_run5.npy
#       fish9_final_predictions_reservoir_test_run5.npy
#     seq_20/
#       fish9_final_predictions_bert_test_run5.npy
#       fish9_final_predictions_deepseek_moe_test_run5.npy
#       fish9_final_predictions_gpt2_pretrained_test_run5.npy
#       fish9_final_predictions_lstm_test_run5.npy
#       fish9_final_predictions_reservoir_test_run5.npy
#     seq_5/
#       fish9_final_predictions_bert_test_run5.npy
#       fish9_final_predictions_deepseek_moe_test_run5.npy
#       fish9_final_predictions_gpt2_pretrained_test_run5.npy
#       fish9_final_predictions_lstm_test_run5.npy
#       fish9_final_predictions_reservoir_test_run5.npy
#   run_6/
#     seq_10/
#       fish9_final_predictions_bert_test_run6.npy
#       fish9_final_predictions_deepseek_moe_test_run6.npy
#       fish9_final_predictions_gpt2_pretrained_test_run6.npy
#       fish9_final_predictions_lstm_test_run6.npy
#       fish9_final_predictions_reservoir_test_run6.npy
#     seq_15/
#       fish9_final_predictions_bert_test_run6.npy
#       fish9_final_predictions_deepseek_moe_test_run6.npy
#       fish9_final_predictions_gpt2_pretrained_test_run6.npy
#       fish9_final_predictions_lstm_test_run6.npy
#       fish9_final_predictions_reservoir_test_run6.npy
#     seq_20/
#       fish9_final_predictions_bert_test_run6.npy
#       fish9_final_predictions_deepseek_moe_test_run6.npy
#       fish9_final_predictions_gpt2_pretrained_test_run6.npy
#       fish9_final_predictions_lstm_test_run6.npy
#       fish9_final_predictions_reservoir_test_run6.npy
#     seq_5/
#       fish9_final_predictions_bert_test_run6.npy
#       fish9_final_predictions_deepseek_moe_test_run6.npy
#       fish9_final_predictions_gpt2_pretrained_test_run6.npy
#       fish9_final_predictions_lstm_test_run6.npy
#       fish9_final_predictions_reservoir_test_run6.npy
#   run_7/
#     seq_10/
#       fish9_final_predictions_bert_test_run7.npy
#       fish9_final_predictions_deepseek_moe_test_run7.npy
#       fish9_final_predictions_gpt2_pretrained_test_run7.npy
#       fish9_final_predictions_lstm_test_run7.npy
#       fish9_final_predictions_reservoir_test_run7.npy
#     seq_15/
#       fish9_final_predictions_bert_test_run7.npy
#       fish9_final_predictions_deepseek_moe_test_run7.npy
#       fish9_final_predictions_gpt2_pretrained_test_run7.npy
#       fish9_final_predictions_lstm_test_run7.npy
#       fish9_final_predictions_reservoir_test_run7.npy
#     seq_20/
#       fish9_final_predictions_bert_test_run7.npy
#       fish9_final_predictions_deepseek_moe_test_run7.npy
#       fish9_final_predictions_gpt2_pretrained_test_run7.npy
#       fish9_final_predictions_lstm_test_run7.npy
#       fish9_final_predictions_reservoir_test_run7.npy
#     seq_5/
#       fish9_final_predictions_bert_test_run7.npy
#       fish9_final_predictions_deepseek_moe_test_run7.npy
#       fish9_final_predictions_gpt2_pretrained_test_run7.npy
#       fish9_final_predictions_lstm_test_run7.npy
#       fish9_final_predictions_reservoir_test_run7.npy
#   run_8/
#     seq_10/
#       fish9_final_predictions_bert_test_run8.npy
#       fish9_final_predictions_deepseek_moe_test_run8.npy
#       fish9_final_predictions_gpt2_pretrained_test_run8.npy
#       fish9_final_predictions_lstm_test_run8.npy
#       fish9_final_predictions_reservoir_test_run8.npy
#     seq_15/
#       fish9_final_predictions_bert_test_run8.npy
#       fish9_final_predictions_deepseek_moe_test_run8.npy
#       fish9_final_predictions_gpt2_pretrained_test_run8.npy
#       fish9_final_predictions_lstm_test_run8.npy
#       fish9_final_predictions_reservoir_test_run8.npy
#     seq_20/
#       fish9_final_predictions_bert_test_run8.npy
#       fish9_final_predictions_deepseek_moe_test_run8.npy
#       fish9_final_predictions_gpt2_pretrained_test_run8.npy
#       fish9_final_predictions_lstm_test_run8.npy
#       fish9_final_predictions_reservoir_test_run8.npy
#     seq_5/
#       fish9_final_predictions_bert_test_run8.npy
#       fish9_final_predictions_deepseek_moe_test_run8.npy
#       fish9_final_predictions_gpt2_pretrained_test_run8.npy
#       fish9_final_predictions_lstm_test_run8.npy
#       fish9_final_predictions_reservoir_test_run8.npy
#   run_9/
#     seq_10/
#       fish9_final_predictions_bert_test_run9.npy
#       fish9_final_predictions_deepseek_moe_test_run9.npy
#       fish9_final_predictions_gpt2_pretrained_test_run9.npy
#       fish9_final_predictions_lstm_test_run9.npy
#       fish9_final_predictions_reservoir_test_run9.npy
#     seq_15/
#       fish9_final_predictions_bert_test_run9.npy
#       fish9_final_predictions_deepseek_moe_test_run9.npy
#       fish9_final_predictions_gpt2_pretrained_test_run9.npy
#       fish9_final_predictions_lstm_test_run9.npy
#       fish9_final_predictions_reservoir_test_run9.npy
#     seq_20/
#       fish9_final_predictions_bert_test_run9.npy
#       fish9_final_predictions_deepseek_moe_test_run9.npy
#       fish9_final_predictions_gpt2_pretrained_test_run9.npy
#       fish9_final_predictions_lstm_test_run9.npy
#       fish9_final_predictions_reservoir_test_run9.npy
#     seq_5/
#       fish9_final_predictions_bert_test_run9.npy
#       fish9_final_predictions_deepseek_moe_test_run9.npy
#       fish9_final_predictions_gpt2_pretrained_test_run9.npy
#       fish9_final_predictions_lstm_test_run9.npy
#       fish9_final_predictions_reservoir_test_run9.npy

# %%
# fish 10 sequence 5 looks good...
# fish 11 sequence 10 looks good...
# fish 11 sequence 15 looks good..
# fish 11 sequence 20 looks good..

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import sem

# ─── CONFIG ───────────────────────────────────────────────────────────────────
fish             = 11
seq              = 10
use_components   = [0,1,2,3,4,5]
num_runs         = 10
models_to_use    = ["GPT-2 (base)", "LSTM", "DeepSeek-coder-7b", "BERT-small"]
panel_plot       = True                       # True = per-theta panels; False = summed-tail

# Figure size control
width            = 3    # total figure width (inches)
height_per_panel = 1    # height per subplot (inches)

# Time‐frame selection: None for full, or (start,end)
frame_range      = None

# ─── I/O & MODEL MAPPING ───────────────────────────────────────────────────────
RESULTS_ROOT = os.path.abspath(
    os.path.join(os.getcwd(), os.pardir, os.pardir,
                 "external_data","nlp4neuro","results_april30","experiment_1")
)
full_model_map = {
    "GPT-2 (base)"      : ("gpt2_pretrained", "#1f77b4"),
    "LSTM"              : ("lstm",            "#ff7f0e"),
    "DeepSeek-coder-7b" : ("deepseek_moe",    "#000000"),
    "BERT-small"        : ("bert",            "#7f7f7f"),
}
model_map = {m: full_model_map[m] for m in models_to_use}

# ─── LOAD & SLICE GROUND TRUTH ────────────────────────────────────────────────
gt_path  = os.path.join(
    RESULTS_ROOT, f"fish{fish}",
    f"fish{fish}_final_predictions_groundtruth_test.npy"
)
y_true   = np.load(gt_path)                    # shape (T,6)
time_vec = np.arange(y_true.shape[0]) / 1.1    # 1.1 Hz sampling

if frame_range is not None:
    start, end = frame_range
    y_true     = y_true[start:end]
    time_vec   = time_vec[start:end]

plt.rcParams["pdf.fonttype"] = 42

if panel_plot:
    # ─── PANEL VIEW ─────────────────────────────────────────────────────────
    # compute baseline per component from first 50 frames
    baselines = {comp: np.mean(y_true[:50, comp]) for comp in use_components}

    n = len(use_components)
    fig, axes = plt.subplots(
        n, 1, sharex=True,
        figsize=(width, height_per_panel * n),
        dpi=300
    )

    for idx, comp in enumerate(use_components):
        ax = axes[idx]
        # ground truth (shifted by baseline)
        gt_label = "Ground truth" if idx == 0 else None
        y_gt     = y_true[:, comp] - baselines[comp]
        ax.plot(time_vec, y_gt,
                color="red", lw=1.5, label=gt_label)

        # each model
        for model_name, (key, color) in model_map.items():
            runs = []
            for run in range(1, num_runs + 1):
                fpath = os.path.join(
                    RESULTS_ROOT,
                    f"fish{fish}", f"run_{run}",
                    f"seq_{seq}",
                    f"fish{fish}_final_predictions_{key}_test_run{run}.npy"
                )
                if not os.path.isfile(fpath):
                    continue
                pred = np.load(fpath)
                if frame_range is not None:
                    pred = pred[start:end]
                runs.append(pred[:, comp] - baselines[comp])

            if not runs:
                continue

            data    = np.vstack(runs)
            mean_ts = data.mean(axis=0)
            sem_ts  = sem(data, axis=0)
            mlabel  = model_name if idx == 0 else None

            ax.plot(time_vec, mean_ts,
                    color=color, lw=1.2, label=mlabel)
            ax.fill_between(time_vec,
                            mean_ts - sem_ts,
                            mean_ts + sem_ts,
                            color=color, alpha=0.2)

        ax.set_ylabel(rf"$\Delta\theta_{{{comp}}}$")
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)

    # single-row legend above panels
    handles, labels = axes[0].get_legend_handles_labels()
    fig.legend(
        handles, labels,
        ncol=len(handles),
        frameon=False,
        loc="lower center",
        bbox_to_anchor=(0.5, 1.0),
        bbox_transform=fig.transFigure
    )
    fig.subplots_adjust(top=0.85)
    axes[-1].set_xlabel("Time (s)")
    fig.tight_layout()
    out_name = f"tail_panels_fish{fish}_s{seq}_baseline.pdf"

else:
    # ─── SUMMED-TAIL VIEW ─────────────────────────────────────────────────────
    # baseline from ground truth sum
    y_sum_full    = y_true[:, use_components].sum(axis=1)
    baseline_sum  = np.mean(y_sum_full[:50])
    y_sum_shifted = y_sum_full - baseline_sum

    fig, ax = plt.subplots(figsize=(width, height_per_panel), dpi=300)

    ax.plot(time_vec, y_sum_shifted,
            color="red", lw=1.5, label="Ground truth")

    for model_name, (key, color) in model_map.items():
        runs = []
        for run in range(1, num_runs + 1):
            fpath = os.path.join(
                RESULTS_ROOT,
                f"fish{fish}", f"run_{run}",
                f"seq_{seq}",
                f"fish{fish}_final_predictions_{key}_test_run{run}.npy"
            )
            if not os.path.isfile(fpath):
                continue
            pred = np.load(fpath)
            if frame_range is not None:
                pred = pred[start:end]
            runs.append(pred[:, use_components].sum(axis=1) - baseline_sum)

        if not runs:
            continue

        data    = np.vstack(runs)
        mean_ts = data.mean(axis=0)
        sem_ts  = sem(data, axis=0)

        ax.plot(time_vec, mean_ts,
                color=color, lw=1.2, label=model_name)
        ax.fill_between(time_vec,
                        mean_ts - sem_ts,
                        mean_ts + sem_ts,
                        color=color, alpha=0.2)

    ax.set_xlabel("Time (s)")
    ax.set_ylabel(r"$\Delta \sum_{i}\theta_i$")
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.legend(ncol=1, frameon=False, loc="upper right")
    fig.tight_layout()
    out_name = f"tail_sum_fish{fish}_s{seq}_baseline.pdf"

# ─── SAVE ─────────────────────────────────────────────────────────────────────
out_file = os.path.join(RESULTS_ROOT, out_name)
fig.savefig(out_file, dpi=300, bbox_inches="tight")
print("Saved to", out_file)
# Out:
# Saved to C:\Users\jacob\OneDrive\Documents\GitHub\external_data\nlp4neuro\results_april30\experiment_1\tail_panels_fish11_s10_baseline.pdf

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import sem, t
from matplotlib.lines import Line2D

# ─── CONFIG ───────────────────────────────────────────────────────────────────
fish                   = 11
seq                    = 10
use_components         = [0,1,2,3,4,5]
num_runs               = 10
models_to_use          = ["GPT-2 (base)", "LSTM", "DeepSeek-coder-7b", "BERT-small", "Reservoir computer"]
panel_plot             = True   # True = per-theta panels; False = summed-tail

# Plot RC only in first panel, and control legend style
reservoir_in_legend    = True  # ← toggle this to get a single 2×3 legend (all 5 models + GT)

# Optional: plot a single run instead of the mean ± CI
single_run             = None   # set to 1..num_runs or None

# Figure size & sampling
width                  = 3      # inches
height_per_panel       = 1      # inches per subplot
frame_range            = None   # e.g. (start, end) or None
sampling_rate_hz       = 1.1

# ─── I/O & MODEL MAPPING ───────────────────────────────────────────────────────
RESULTS_ROOT = os.path.abspath(
    os.path.join(os.getcwd(), os.pardir, os.pardir,
                 "external_data","nlp4neuro","results_april30","experiment_1")
)
full_model_map = {
    "GPT-2 (base)"      : ("gpt2_pretrained", "#1f77b4"),
    "LSTM"              : ("lstm",            "#ff7f0e"),
    "DeepSeek-coder-7b" : ("deepseek_moe",    "#000000"),
    "BERT-small"        : ("bert",            "#7f7f7f"),
    "Reservoir computer"                : ("reservoir",       "purple"),
}
model_map = {m: full_model_map[m] for m in models_to_use}

# ─── LOAD GROUND TRUTH ─────────────────────────────────────────────────────────
gt_path  = os.path.join(
    RESULTS_ROOT, f"fish{fish}",
    f"fish{fish}_final_predictions_groundtruth_test.npy"
)
y_true   = np.load(gt_path)                         # shape (T,6)
time_vec = np.arange(y_true.shape[0]) / sampling_rate_hz

if frame_range is not None:
    start, end = frame_range
    y_true      = y_true[start:end]
    time_vec    = time_vec[start:end]

plt.rcParams["pdf.fonttype"] = 42

# ─── RUN SELECTION HELPER ─────────────────────────────────────────────────────
def get_run_list():
    return [single_run] if single_run is not None else range(1, num_runs + 1)

# ─── PANEL PLOT ───────────────────────────────────────────────────────────────
if panel_plot:
    baselines = {c: np.mean(y_true[:50, c]) for c in use_components}
    n = len(use_components)
    fig, axes = plt.subplots(n, 1, sharex=True,
                             figsize=(width, height_per_panel * n),
                             dpi=300)

    for idx, comp in enumerate(use_components):
        ax = axes[idx]

        # ── Ground truth
        gt_label = "Ground truth" if idx == 0 else None
        y_gt      = y_true[:, comp] - baselines[comp]
        ax.plot(time_vec, y_gt,
                color="red", lw=0.5, label=gt_label)

        # ── Models (but RC only on first panel)
        for model_name, (key, color) in model_map.items():
            if model_name == "Reservoir computer" and idx != 0:
                continue

            runs = []
            for run in get_run_list():
                fpath = os.path.join(
                    RESULTS_ROOT,
                    f"fish{fish}", f"run_{run}",
                    f"seq_{seq}",
                    f"fish{fish}_final_predictions_{key}_test_run{run}.npy"
                )
                if not os.path.isfile(fpath):
                    continue
                pred = np.load(fpath)
                if frame_range is not None:
                    pred = pred[start:end]
                runs.append(pred[:, comp] - baselines[comp])

            if not runs:
                continue

            data    = np.vstack(runs)
            mean_ts = data.mean(axis=0)
            sem_ts  = sem(data, axis=0)
            df      = data.shape[0] - 1
            ci_mult = t.ppf(0.975, df=df) if df > 0 else 0
            ci      = ci_mult * sem_ts

            mlabel = model_name if idx == 0 else None
            ax.plot(time_vec, mean_ts,
                    color=color, lw=0.5, label=mlabel)
            ax.fill_between(time_vec,
                            mean_ts - ci,
                            mean_ts + ci,
                            color=color, alpha=0.2)

        ax.set_ylabel(rf"$\Delta\theta_{{{comp}}}$")
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)

    # ─── LEGEND(S) ────────────────────────────────────────────────────────────
    handles, labels = axes[0].get_legend_handles_labels()
    hdict           = dict(zip(labels, handles))

    if reservoir_in_legend:
        # single 2×3 legend: 5 models + ground truth
        ordered = [
            "LSTM",
            "BERT-small",
            "GPT-2 (base)",
            "DeepSeek-coder-7b",
            "Reservoir computer",
            "Ground truth"
        ]
        leg_h = [hdict[l] for l in ordered]
        fig.legend(
            leg_h, ordered,
            ncol=2,
            frameon=False,
            loc="lower center",
            bbox_to_anchor=(0.5, 1.00),
            bbox_transform=fig.transFigure
        )
        fig.subplots_adjust(top=0.85)

    else:
        # fallback: two legends
        # 1) 2×2 of the four non-RC models
        model_order   = ["LSTM", "BERT-small", "GPT-2 (base)", "DeepSeek-coder-7b"]
        model_handles = [hdict[m] for m in model_order]
        fig.legend(
            model_handles, model_order,
            ncol=2,
            frameon=False,
            loc="lower center",
            bbox_to_anchor=(0.5, 1.00),
            bbox_transform=fig.transFigure
        )

        # 2) Ground truth below
        gt_hdl = hdict["Ground truth"]
        fig.legend(
            [gt_hdl], ["Ground truth"],
            ncol=1,
            frameon=False,
            loc="lower center",
            bbox_to_anchor=(0.5, 0.95),
            bbox_transform=fig.transFigure
        )
        fig.subplots_adjust(top=0.85)

    axes[-1].set_xlabel("Time (s)")
    fig.tight_layout()
    out_name = f"tail_panels_fish{fish}_s{seq}_baseline.pdf"

# ─── SUMMED-TAIL PLOT ─────────────────────────────────────────────────────────
else:
    y_sum_full    = y_true[:, use_components].sum(axis=1)
    baseline_sum  = np.mean(y_sum_full[:50])
    y_sum_shifted = y_sum_full - baseline_sum

    fig, ax = plt.subplots(figsize=(width, height_per_panel), dpi=300)
    ax.plot(time_vec, y_sum_shifted,
            color="red", lw=1.0, label="Ground truth")

    for model_name, (key, color) in model_map.items():
        runs = []
        for run in get_run_list():
            fpath = os.path.join(
                RESULTS_ROOT,
                f"fish{fish}", f"run_{run}",
                f"seq_{seq}",
                f"fish{fish}_final_predictions_{key}_test_run{run}.npy"
            )
            if not os.path.isfile(fpath):
                continue
            pred = np.load(fpath)
            if frame_range is not None:
                pred = pred[start:end]
            runs.append(pred[:, use_components].sum(axis=1) - baseline_sum)

        if not runs:
            continue

        data    = np.vstack(runs)
        mean_ts = data.mean(axis=0)
        sem_ts  = sem(data, axis=0)
        df      = data.shape[0] - 1
        ci_mult = t.ppf(0.975, df=df) if df > 0 else 0
        ci      = ci_mult * sem_ts

        ax.plot(time_vec, mean_ts,
                color=color, lw=0.8, label=model_name)
        ax.fill_between(time_vec,
                        mean_ts - ci,
                        mean_ts + ci,
                        color=color, alpha=0.2)

    ax.set_xlabel("Time (s)")
    ax.set_ylabel(r"$\Delta \sum_{i}\theta_i$")
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.legend(ncol=2, frameon=False, loc="upper right")

    fig.tight_layout()
    out_name = f"tail_sum_fish{fish}_s{seq}_baseline.pdf"

# ─── SAVE ─────────────────────────────────────────────────────────────────────
out_file = os.path.join(RESULTS_ROOT, out_name)
fig.savefig(out_file, dpi=300, bbox_inches="tight")
print("Saved to", out_file)
# Out:
# Saved to C:\Users\jacob\OneDrive\Documents\GitHub\external_data\nlp4neuro\results_april30\experiment_1\tail_panels_fish11_s10_baseline.pdf

# %%
# fish 11 seq 10 run 1... this looks pretty good.

# print(y_true[:,5])
import seaborn as sns

run = 1
component = 0

ff = np.load(f"{RESULTS_ROOT}/fish11/run_{run}/seq_10/fish11_final_predictions_deepseek_moe_test_run{run}.npy")
sns.lineplot(ff[:,component])
print(ff.shape)

ff2 = np.load(f"{RESULTS_ROOT}/fish11/fish11_final_predictions_groundtruth_test.npy")
sns.lineplot(ff2[:,component])
print(ff2.shape)

ff3 = np.load(f"{RESULTS_ROOT}/fish11/run_{run}/seq_10/fish11_final_predictions_lstm_test_run{run}.npy")
sns.lineplot(ff3[:,component], color='red')

from sklearn.metrics import root_mean_squared_error

print(root_mean_squared_error(ff2, ff))
print(root_mean_squared_error(ff2, ff3))
# Out:
# (560, 6)
# (560, 6)
# 0.04567119789200389
# 0.052422608477468415

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import sem

# ─── CONFIG ───────────────────────────────────────────────────────────────────
fish             = 11
seq              = 10
use_components   = [0,1,2,3,4,5]
num_runs         = 10
models_to_use    = []
panel_plot       = True                       # True = per-theta panels; False = summed-tail

# Figure size control
width            = 3.0    # total figure width (inches)
height_per_panel = 0.8    # height per subplot (inches)

# Time‐frame selection: None for full, or (start,end)
frame_range      = None

# ─── I/O & MODEL MAPPING ───────────────────────────────────────────────────────
RESULTS_ROOT = os.path.abspath(
    os.path.join(os.getcwd(), os.pardir, os.pardir,
                 "external_data","nlp4neuro","results_april30","experiment_1")
)
full_model_map = {
    "GPT-2 (base)"      : ("gpt2_pretrained", "#1f77b4"),
    "LSTM"              : ("lstm",            "#ff7f0e"),
    "DeepSeek-coder-7b" : ("deepseek_moe",    "#000000"),
    "BERT-small"        : ("bert",            "#7f7f7f"),
}
model_map = {m: full_model_map[m] for m in models_to_use}

# ─── LOAD & SLICE GROUND TRUTH ────────────────────────────────────────────────
gt_path  = os.path.join(
    RESULTS_ROOT, f"fish{fish}",
    f"fish{fish}_final_predictions_groundtruth_test.npy"
)
y_true   = np.load(gt_path)                    # shape (T,6)
time_vec = np.arange(y_true.shape[0]) / 1.1    # 1.1 Hz sampling

if frame_range is not None:
    start, end = frame_range
    y_true     = y_true[start:end]
    time_vec   = time_vec[start:end]

plt.rcParams["pdf.fonttype"] = 42

if panel_plot:
    # ─── PANEL VIEW ─────────────────────────────────────────────────────────
    # compute baseline per component from first 50 frames
    baselines = {comp: np.mean(y_true[:50, comp]) for comp in use_components}

    n = len(use_components)
    fig, axes = plt.subplots(
        n, 1, sharex=True,
        figsize=(width, height_per_panel * n),
        dpi=300
    )

    for idx, comp in enumerate(use_components):
        ax = axes[idx]
        # ground truth (shifted by baseline)
        gt_label = "Ground truth" if idx == 0 else None
        y_gt     = y_true[:, comp] - baselines[comp]
        ax.plot(time_vec, y_gt,
                color="red", lw=1.5, label=gt_label)

        # each model
        for model_name, (key, color) in model_map.items():
            runs = []
            for run in range(1, num_runs + 1):
                fpath = os.path.join(
                    RESULTS_ROOT,
                    f"fish{fish}", f"run_{run}",
                    f"seq_{seq}",
                    f"fish{fish}_final_predictions_{key}_test_run{run}.npy"
                )
                if not os.path.isfile(fpath):
                    continue
                pred = np.load(fpath)
                if frame_range is not None:
                    pred = pred[start:end]
                runs.append(pred[:, comp] - baselines[comp])

            if not runs:
                continue

            data    = np.vstack(runs)
            mean_ts = data.mean(axis=0)
            sem_ts  = sem(data, axis=0)
            mlabel  = model_name if idx == 0 else None

            ax.plot(time_vec, mean_ts,
                    color=color, lw=1.2, label=mlabel)
            ax.fill_between(time_vec,
                            mean_ts - sem_ts,
                            mean_ts + sem_ts,
                            color=color, alpha=0.2)

        ax.set_ylabel(rf"$\Delta\theta_{{{comp}}}$")
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)

    # single-row legend above panels
    handles, labels = axes[0].get_legend_handles_labels()
    fig.legend(
        handles, labels,
        ncol=len(handles),
        frameon=False,
        loc="lower center",
        bbox_to_anchor=(0.5, 1.0),
        bbox_transform=fig.transFigure
    )
    fig.subplots_adjust(top=0.85)
    axes[-1].set_xlabel("Time (s)")
    fig.tight_layout()
    out_name = f"tail_panels_fish{fish}_s{seq}_baseline.pdf"

else:
    # ─── SUMMED-TAIL VIEW ─────────────────────────────────────────────────────
    # baseline from ground truth sum
    y_sum_full    = y_true[:, use_components].sum(axis=1)
    baseline_sum  = np.mean(y_sum_full[:50])
    y_sum_shifted = y_sum_full - baseline_sum

    fig, ax = plt.subplots(figsize=(width, height_per_panel), dpi=300)

    ax.plot(time_vec, y_sum_shifted,
            color="red", lw=1.5, label="Ground truth")

    for model_name, (key, color) in model_map.items():
        runs = []
        for run in range(1, num_runs + 1):
            fpath = os.path.join(
                RESULTS_ROOT,
                f"fish{fish}", f"run_{run}",
                f"seq_{seq}",
                f"fish{fish}_final_predictions_{key}_test_run{run}.npy"
            )
            if not os.path.isfile(fpath):
                continue
            pred = np.load(fpath)
            if frame_range is not None:
                pred = pred[start:end]
            runs.append(pred[:, use_components].sum(axis=1) - baseline_sum)

        if not runs:
            continue

        data    = np.vstack(runs)
        mean_ts = data.mean(axis=0)
        sem_ts  = sem(data, axis=0)

        ax.plot(time_vec, mean_ts,
                color=color, lw=1.2, label=model_name)
        ax.fill_between(time_vec,
                        mean_ts - sem_ts,
                        mean_ts + sem_ts,
                        color=color, alpha=0.2)

    ax.set_xlabel("Time (s)")
    ax.set_ylabel(r"$\Delta \sum_{i}\theta_i$")
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.legend(ncol=1, frameon=False, loc="upper right")
    fig.tight_layout()
    out_name = f"tail_sum_fish{fish}_s{seq}_baseline.pdf"

# ─── SAVE ─────────────────────────────────────────────────────────────────────
out_file = os.path.join(RESULTS_ROOT, out_name)
fig.savefig(out_file, dpi=300, bbox_inches="tight")
print("Saved to", out_file)
# Out:
# Saved to C:\Users\jacob\OneDrive\Documents\GitHub\external_data\nlp4neuro\results_april30\experiment_1\tail_panels_fish11_s10_baseline.pdf
