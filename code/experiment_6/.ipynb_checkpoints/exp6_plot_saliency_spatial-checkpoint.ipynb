# %%
# plot saliency maps of top neurons onto fish images.. only 11-13

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\jacob\OneDrive\Documents\GitHub\nlp4neuro\code\experiment_6

# %%
import os

# adjust this relative path until it points at your experiment_6 results folder
RESULTS_ROOT = os.path.abspath(
    os.path.join(os.getcwd(), os.pardir, os.pardir, os.pardir,
                 "external_data", "nlp4neuro", "results_april30", "experiment_6")
)

print("Looking in:", RESULTS_ROOT)
for root, dirs, files in os.walk(RESULTS_ROOT):
    # only print the first two levels to keep it short
    rel = os.path.relpath(root, RESULTS_ROOT)
    depth = rel.count(os.sep)
    if depth <= 2:
        indent = "  " * depth
        print(f"{indent}{os.path.basename(root)}/")
        for f in files:
            if f.endswith(".npy") or f.endswith(".png"):
                print(f"{indent}  {f}")
# Out:
# Looking in: C:\Users\jacob\OneDrive\Documents\GitHub\external_data\nlp4neuro\results_april30\experiment_6
# experiment_6/
# fish10/
#   fish10_final_predictions_groundtruth_test.npy
#   fish10_final_predictions_groundtruth_val.npy
#   test_gt.npy
#   val_gt.npy
#   run_1/
#     seq_10/
#       importance.npy
#       preds.npy
#       top20_saliency.png
#   run_2/
#     seq_10/
#       importance.npy
#       preds.npy
#       top20_saliency.png
#   run_3/
#     seq_10/
#       importance.npy
#       preds.npy
#       top20_saliency.png
#   run_4/
#     seq_10/
#       importance.npy
#       preds.npy
#       top20_saliency.png
#   run_5/
#     seq_10/
#       importance.npy
#       preds.npy
#       top20_saliency.png
# fish11/
#   fish11_final_predictions_groundtruth_test.npy
#   fish11_final_predictions_groundtruth_val.npy
#   fish11_saliency_overlay.png
#   test_gt.npy
#   val_gt.npy
#   run_1/
#     seq_10/
#       importance.npy
#       preds.npy
#       top20_saliency.png
#   run_2/
#     seq_10/
#       importance.npy
#       preds.npy
#       top20_saliency.png
#   run_3/
#     seq_10/
#       importance.npy
#       preds.npy
#       top20_saliency.png
#   run_4/
#     seq_10/
#       importance.npy
#       preds.npy
#       top20_saliency.png
#   run_5/
#     seq_10/
#       importance.npy
#       preds.npy
#       top20_saliency.png
# fish12/
#   fish12_final_predictions_groundtruth_test.npy
#   fish12_final_predictions_groundtruth_val.npy
#   fish12_saliency_overlay.png
#   test_gt.npy
#   val_gt.npy
#   run_1/
#     seq_10/
#       importance.npy
#       preds.npy
#       top20_saliency.png
#   run_2/
#     seq_10/
#       importance.npy
#       preds.npy
#       top20_saliency.png
#   run_3/
#     seq_10/
#       importance.npy
#       preds.npy
#       top20_saliency.png
#   run_4/
#     seq_10/
#       importance.npy
#       preds.npy
#       top20_saliency.png
#   run_5/
#     seq_10/
#       importance.npy
#       preds.npy
#       top20_saliency.png
# fish13/
#   fish13_final_predictions_groundtruth_test.npy
#   fish13_final_predictions_groundtruth_val.npy
#   fish13_saliency_overlay.png
#   test_gt.npy
#   val_gt.npy
#   run_1/
#     seq_10/
#       importance.npy
#       preds.npy
#       top20_saliency.png
#   run_2/
#     seq_10/
#       importance.npy
#       preds.npy
#       top20_saliency.png
#   run_3/
#     seq_10/
#       importance.npy
#       preds.npy
#       top20_saliency.png
#   run_4/
#     seq_10/
#       importance.npy
#       preds.npy
#       top20_saliency.png
#   run_5/
#     seq_10/
#       importance.npy
#       preds.npy
#       top20_saliency.png
# fish9/
#   fish9_final_predictions_groundtruth_test.npy
#   fish9_final_predictions_groundtruth_val.npy
#   test_gt.npy
#   val_gt.npy
#   run_1/
#     seq_10/
#       importance.npy
#       preds.npy
#       top20_saliency.png
#   run_2/
#     seq_10/
#       importance.npy
#       preds.npy
#       top20_saliency.png
#   run_3/
#     seq_10/
#       importance.npy
#       preds.npy
#       top20_saliency.png
#   run_4/
#     seq_10/
#       importance.npy
#       preds.npy
#       top20_saliency.png
#   run_5/
#     seq_10/
#       importance.npy
#       preds.npy
#       top20_saliency.png

# %%
# ────────────────────────────────────────────────────────────────────────────────
# Cell 1: Imports & Corrected Base Paths
# ────────────────────────────────────────────────────────────────────────────────
import os, ast
import numpy as np, pandas as pd, matplotlib.pyplot as plt
from PIL import Image

# cwd: …/GitHub/nlp4neuro/code/experiment_6
EXPT_DIR = os.path.abspath(
    os.path.join(os.getcwd(), os.pardir, os.pardir, os.pardir,
                 "external_data", "nlp4neuro", "results_april30", "experiment_6")
)
print("Experiment dir:", EXPT_DIR)

NL_ROOT = os.path.abspath(
    os.path.join(os.getcwd(), os.pardir, os.pardir, os.pardir,
                 "external_data", "nlp4neuro")
)
print("NL root:", NL_ROOT)

IMG_PATTERN = os.path.join(NL_ROOT, "fish{fish}_images")
fish_list   = [11, 12, 13]

# Overlay settings
TOP_K, DOT_COLOR, DOT_EDGE, DOT_ALPHA = 20, "red", "white", 0.8
DOT_MIN, DOT_MAX = 50, 300
# Out:
# Experiment dir: C:\Users\jacob\OneDrive\Documents\GitHub\external_data\nlp4neuro\results_april30\experiment_6
# NL root: C:\Users\jacob\OneDrive\Documents\GitHub\external_data\nlp4neuro

# %%
import os
import h5py

# point this at the file you want to inspect
fish = 11
h5_path = os.path.join(
    os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir, os.pardir,
                                  "external_data", "nlp4neuro", f"fish{fish}_images")),
    "functional_types_df.h5"
)

print("Inspecting:", h5_path)
import pandas as pd

pd.read_hdf(h5_path)
# Out:
# Inspecting: C:\Users\jacob\OneDrive\Documents\GitHub\external_data\nlp4neuro\fish11_images\functional_types_df.h5
#       resp_cell_id  omr_neur_id  stim_neur_id neur_coords    plane region  \
# 0           resp_0            0        1365.0   [71, 431]  plane_0     Hb
# 1           resp_1            1        2089.0  [467, 196]  plane_0    NaN
# 2           resp_2            2        2301.0  [446, 280]  plane_0    NaN
# 3           resp_3            3         241.0  [161, 168]  plane_0     Pt
# 4           resp_4            4         343.0  [455, 299]  plane_0    NaN
# ...            ...          ...           ...         ...      ...    ...
# 14010      stim_11          876         759.0  [185, 220]  plane_4     Pt
# 14011      stim_12         1688        1692.0  [153, 187]  plane_4     Pt
# 14012      stim_13         1854        1552.0  [143, 226]  plane_4     Pt
# 14013      stim_14          410        1315.0  [293, 189]  plane_5     Pt
# 14014      stim_15          742         845.0  [155, 187]  plane_5     Pt
#
#       visual_barcode                                   motion_responses  \
# 0               Mm_L  {'medial_left': {'mean': [0.31887074808279675,...
# 1               None  {'medial_left': {'mean': [-0.06623511513074239...
# 2               None  {'medial_left': {'mean': [0.13466171423594156,...
# 3               None  {'medial_left': {'mean': [-0.1321977712213993,...
# 4              oMl_L  {'medial_left': {'mean': [-0.05501520509521166...
# ...              ...                                                ...
# 14010          iMm_L  {'medial_left': {'mean': [0.2277520423134168, ...
# 14011          iMm_L  {'medial_left': {'mean': [-0.07499795903762181...
# 14012            B_L  {'medial_left': {'mean': [0.03487451126178106,...
# 14013            B_R  {'medial_left': {'mean': [-0.07091554316381614...
# 14014          iMm_L  {'medial_left': {'mean': [0.002581611275672912...
#
#        photostim                                      stim_frames  \
# 0          False                                             None
# 1          False                                             None
# 2          False                                             None
# 3          False                                             None
# 4          False                                             None
# ...          ...                                              ...
# 14010       True   [518, 619, 1537, 1931, 2587, 3308, 3832, 4326]
# 14011       True   [257, 717, 1147, 1768, 2554, 2982, 3767, 4033]
# 14012       True  [225, 1042, 1179, 2159, 2392, 3047, 3799, 3968]
# 14013       True    [61, 847, 1406, 2094, 2522, 3275, 3702, 4163]
# 14014       True    [93, 749, 1275, 1801, 2652, 3210, 3637, 4000]
#
#                               stim_events  motor_corr  \
# 0                                    None    0.185897
# 1                                    None    0.072974
# 2                                    None    0.023371
# 3                                    None    0.280545
# 4                                    None    0.104326
# ...                                   ...         ...
# 14010  [15, 17, 44, 55, 74, 95, 110, 124]   -0.005226
# 14011   [7, 20, 32, 50, 73, 85, 108, 115]    0.109901
# 14012   [6, 30, 33, 62, 68, 87, 109, 113]    0.074815
# 14013   [1, 24, 40, 60, 72, 94, 106, 119]    0.132854
# 14014   [2, 21, 36, 51, 76, 92, 104, 114]    0.139141
#
#                                           stim_responses  \
# 0      {'stim_0': [[[-0.61927632  0.31557747  0.22771...
# 1      {'stim_0': [[[ 0.49837932  0.64694609 -0.50894...
# 2      {'stim_0': [[[-0.09996031 -0.35549738  0.45103...
# 3      {'stim_0': [[[ 0.10813485  0.01998925  0.16995...
# 4      {'stim_0': [[[-0.12734897 -0.21270046  0.19130...
# ...                                                  ...
# 14010  {'stim_0': [[[ 0.12433947 -0.06389289 -0.00461...
# 14011  {'stim_0': [[[-0.05931443 -0.04975294  0.20532...
# 14012  {'stim_0': [[[ 0.37774991 -0.0432566   0.06420...
# 14013  {'stim_0': [[[ 0.2103529  -0.34507771  0.22784...
# 14014  {'stim_0': [[[-0.32235833  0.25895913  0.02244...
#
#                                          avg_evoked_df_f significant_trials
# 0      [0.038065001605065395, 0.0021889208632816896, ...                NaN
# 1      [0.20730324720100424, 0.0009667249206161965, -...                NaN
# 2      [-0.007334091466551104, 0.020587050845468587, ...                NaN
# 3      [0.15969398319257772, 0.06495104223651485, 0.1...                NaN
# 4      [-0.062220747764546024, 0.06221156101692064, -...                NaN
# ...                                                  ...                ...
# 14010  [-0.050990364754760695, -0.11934550443905145, ...             [0, 6]
# 14011  [0.017684652990789723, -0.08989377991962967, -...                [1]
# 14012  [0.13950456037916356, -0.15032195876073445, -0...       [0, 4, 6, 7]
# 14013  [-0.045496396684105364, 0.06545263173713273, -...             [1, 4]
# 14014  [-0.031914414313102935, -0.06148892019248053, ...                NaN
#
# [9763 rows x 15 columns]

# %%
# ────────────────────────────────────────────────────────────────────────────────
# Cell 2 (updated): helpers + saliency overlays + region overlay + bar-plot
# ────────────────────────────────────────────────────────────────────────────────
import os, glob, ast
import numpy as np, pandas as pd, matplotlib.pyplot as plt, tifffile
from matplotlib import cm                       # colour map

# ── helper 1: average saliency vector ───────────────────────────────────────────
def load_all_importances(fish_id):
    base = os.path.join(EXPT_DIR, f"fish{fish_id}")
    mats = [np.load(os.path.join(r, "importance.npy"))
            for r,_,fs in os.walk(base) if "importance.npy" in fs]
    return np.vstack(mats).mean(0)              # (neurons_total,)

# ── helper 2: plane-0 table  → sal, coords, region ─────────────────────────────
def plane0_data(fish_id):
    img_dir = IMG_PATTERN.format(fish=fish_id)
    h5 = os.path.join(img_dir, "functional_types_df.h5")
    df = pd.read_hdf(h5)
    df0 = df[df["plane"] == "plane_0"]
    sal0 = load_all_importances(fish_id)[df0.index.values.astype(int)]
    coords0 = np.vstack(df0["neur_coords"].apply(
        lambda x: ast.literal_eval(x) if isinstance(x,str) else x))
    regs0 = df0["region"].fillna("unknown").values
    return sal0, coords0, regs0

# ── helper 3: brighten background image ─────────────────────────────────────────
def bright_plane0_image(fish_id, boost=1.5):
    img_path = glob.glob(os.path.join(IMG_PATTERN.format(fish=fish_id),"plane_0.*"))[0]
    im = tifffile.imread(img_path).astype(float)
    im = (im-im.min())/(im.max()-im.min())      # 0-1
    return np.clip(im*boost,0,1)                # brighten

# store per-fish region saliency for bar-plot
region_maps = []

# ---------- A) overlay top-K saliency dots (transparent PDF) -------------------
for fish in fish_list:
    sal0, coords0, regs0 = plane0_data(fish)
    top = np.argsort(sal0)[-TOP_K:][::-1]
    sizes = ((sal0[top]-sal0[top].min()) /
             (np.ptp(sal0[top])+1e-9))*(DOT_MAX-DOT_MIN)+DOT_MIN

    bg = bright_plane0_image(fish)              # grayscale & bright
    fig, ax = plt.subplots(figsize=(6,6))
    ax.imshow(bg, cmap="gray", vmin=0, vmax=1)
    ax.scatter(coords0[top,0], coords0[top,1],
               s=sizes, c="red", edgecolors="white", alpha=.8)
    ax.axis("off"); fig.patch.set_alpha(0); ax.patch.set_alpha(0)

    out = os.path.join(EXPT_DIR, f"fish{fish}_overlay.pdf")
    fig.savefig(out, transparent=True, bbox_inches="tight")
    plt.close(fig)
    print("saved:", out)

    # region means for bar-plot
    region_maps.append(pd.DataFrame({"sal":sal0,"reg":regs0})
                       .groupby("reg")["sal"].mean())

# ---------- B) region overlay (fish 11) + C) bar-plot --------------------------
# ❶ pick the regions that truly exist (<= REGION_K)
overall_mean = pd.concat(region_maps, axis=1).mean(1)
top_regs     = overall_mean.nlargest(REGION_K).index.tolist()
n_reg        = len(top_regs)                      # could be < REGION_K
colors       = cm.tab10(np.arange(n_reg))         # exactly n_reg colours

# -- region overlay on fish 11 ---------------------------------------------------
sal11, coords11, regs11 = plane0_data(11)
bg11 = bright_plane0_image(11)

fig, ax = plt.subplots(figsize=(6,6))
ax.imshow(bg11, cmap="gray", vmin=0, vmax=1)
for i, r in enumerate(top_regs):
    mask = regs11 == r
    ax.scatter(coords11[mask,0], coords11[mask,1],
               s=50, c=[colors[i]], edgecolors="white")
ax.axis("off"); fig.patch.set_alpha(0); ax.patch.set_alpha(0)

out = os.path.join(EXPT_DIR, "fish11_regions_overlay.pdf")
fig.savefig(out, transparent=True, bbox_inches="tight")
plt.close(fig)
print("saved:", out)

# -- bar-plot across the three fish --------------------------------------------
data = []
for m in region_maps:                       # each m is a Series
    data.append(m.reindex(top_regs).values) # align & keep NaNs

data   = np.vstack(data)                    # shape (3, n_reg)
means  = np.nanmean(data, axis=0)
sems   = np.nanstd(data,  ddof=1, axis=0) / np.sqrt(len(fish_list))

fig, ax = plt.subplots(figsize=(8,4))
x = np.arange(n_reg)
ax.bar(x, means, yerr=sems, capsize=5, color=colors)
ax.set_xticks(x)
ax.set_xticklabels(top_regs, rotation=45, ha="right")
ax.set_ylabel("Mean saliency ± SEM")
fig.patch.set_alpha(0)

out = os.path.join(EXPT_DIR, "region_importance_barplot.pdf")
fig.savefig(out, transparent=True, bbox_inches="tight")
plt.close(fig)
print("saved:", out)
# Out:
# saved: C:\Users\jacob\OneDrive\Documents\GitHub\external_data\nlp4neuro\results_april30\experiment_6\fish11_overlay.pdf
# saved: C:\Users\jacob\OneDrive\Documents\GitHub\external_data\nlp4neuro\results_april30\experiment_6\fish12_overlay.pdf
# saved: C:\Users\jacob\OneDrive\Documents\GitHub\external_data\nlp4neuro\results_april30\experiment_6\fish13_overlay.pdf
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 63
#      60 # ---------- B) region overlay (fish 11) + C) bar-plot --------------------------
#      61 # ❶ pick the regions that truly exist (<= REGION_K)
#      62 overall_mean = pd.concat(region_maps, axis=1).mean(1)
# ---> 63 top_regs     = overall_mean.nlargest(REGION_K).index.tolist()
#      64 n_reg        = len(top_regs)                      # could be < REGION_K
#      65 colors       = cm.tab10(np.arange(n_reg))         # exactly n_reg colours
#
# NameError: name 'REGION_K' is not defined

# %%
# !pip install kneed

# %%
# -------------------- CLUSTERING + OVERLAY + BARPLOT (K=7) --------------------
NEW_K = 8
new_letters = list("ABCDEFGH")[:NEW_K] #change based on num clusters




from sklearn.cluster import KMeans
from scipy.stats import ttest_rel
from scipy.spatial import ConvexHull
import matplotlib.patheffects as pe

# 1) ELBOW PLOT (K=2..15)
Ks, inertias = [], []
for k in range(2, 16):
    Ks.append(k)
    inertias.append(KMeans(n_clusters=k, random_state=0)
                      .fit(np.vstack([plane0_data(f)[1][np.argsort(plane0_data(f)[0])[-TOP_K:]] for f in fish_list]))
                      .inertia_)

fig, ax = plt.subplots()
ax.plot(Ks, inertias, "-o")
ax.set_xlabel("Number of clusters K")
ax.set_ylabel("K-means inertia")
ax.set_title("Elbow plot for pooled top-K neurons")
# mark chosen K=7
ax.axvline(NEW_K, linestyle="--", color="red")
fig.savefig(os.path.join(EXPT_DIR, "elbow_plot.pdf"),
            transparent=True, bbox_inches="tight")
plt.close(fig)
print(f"Saved elbow_plot.pdf; using K={NEW_K} for clustering.")

# 2) FINAL K-MEANS WITH K=7
K_star = NEW_K
# pool top-K neurons coords
xy_pool = np.vstack([
    plane0_data(f)[1][np.argsort(plane0_data(f)[0])[-TOP_K:]]
    for f in fish_list
])
km = KMeans(n_clusters=K_star, random_state=0).fit(xy_pool)

# 3) BUILD cluster tables per fish
cluster_tables = []
for f in fish_list:
    sal, coords, _ = plane0_data(f)
    labels = km.predict(coords)
    cluster_tables.append(pd.DataFrame({
        "sal": sal,
        "cl":  labels,
        "x":   coords[:,0],
        "y":   coords[:,1]
    }))

# 4) COMPUTE mean & SEM per cluster → RANK A..G
means = np.array([tbl.groupby("cl")["sal"].mean() for tbl in cluster_tables]).mean(0)
sems  = np.array([tbl.groupby("cl")["sal"].mean() for tbl in cluster_tables]).std(axis=0, ddof=1) / np.sqrt(len(fish_list))
order = np.argsort(means)[::-1]        # clusters high->low
letters = new_letters     # map top 7 to A..G
letter_map = {cl: letters[i] for i,cl in enumerate(order)}

# 5) OVERLAY on fish11
sal11, coords11, _ = plane0_data(11)
labels11 = km.predict(coords11)
bg      = bright_plane0_image(11)
colors  = cm.tab10(np.arange(K_star))

fig, ax = plt.subplots(figsize=(6,6))
ax.imshow(bg, cmap="gray", vmin=0, vmax=1)
for cl in range(K_star):
    pts = coords11[labels11==cl]
    if pts.size==0: continue
    ax.scatter(pts[:,0], pts[:,1], s=30,
               c=[colors[cl]], edgecolors="white", alpha=0.8)
    if len(pts)>=3:
        hull = ConvexHull(pts)
        poly = pts[hull.vertices]
        ax.plot(*poly.T, linestyle=":", linewidth=1.5, color="white")
    # draw letter
    cx, cy = pts.mean(axis=0)
    ax.text(cx, cy, letter_map[cl],
            color="white", fontsize=12, weight="bold",
            ha="center", va="center",
            path_effects=[pe.Stroke(linewidth=2, foreground="black"), pe.Normal()])

ax.axis("off"); fig.patch.set_alpha(0); ax.patch.set_alpha(0)
fig.savefig(os.path.join(EXPT_DIR, "fish11_clusters_overlay.pdf"),
            transparent=True, bbox_inches="tight")
plt.close(fig)
print("Saved fish11_clusters_overlay.pdf")

# 6) BAR PLOT with ranked clusters & significance
# prepare per-cluster per-fish
data = np.vstack([
    tbl.groupby("cl")["sal"].mean().reindex(order).values
    for tbl in cluster_tables
])  # shape (3, K_star)
bar_means = data.mean(axis=0)
bar_sems  = data.std(axis=0, ddof=1) / np.sqrt(len(fish_list))

fig, ax = plt.subplots(figsize=(8,4))
x = np.arange(K_star)
ax.bar(x, bar_means, yerr=bar_sems, capsize=5, color=colors[order])
ax.set_xticks(x)
ax.set_xticklabels([letters[i] for i in range(K_star)], fontsize=12)
ax.set_ylabel("Mean saliency ± SEM")

# significance: for each i, compare against all j>i (one-tailed)
y0 = bar_means.max() + bar_sems.max()*2
h  = y0 * 0.05
for i in range(K_star-1):
    y = y0 + h*i
    for j in range(i+1, K_star):
        t, p = ttest_rel(data[:,i], data[:,j], nan_policy="omit")
        p_one = p/2 if t>0 else 1.0
        if p_one < 0.05:
            ax.plot([x[i], x[j]], [y, y], c="black", lw=1)
            star = "***" if p_one<0.001 else "**" if p_one<0.01 else "*"
            ax.text((x[i]+x[j])/2, y+h*0.2, star,
                    ha="center", va="bottom", color="black", fontsize=12)

fig.patch.set_alpha(0)
fig.savefig(os.path.join(EXPT_DIR, "cluster_importance_barplot.pdf"),
            transparent=True, bbox_inches="tight")
plt.close(fig)
print("Saved cluster_importance_barplot.pdf")

# %% [markdown]
# # top 20 and bot 20 per each fish

# %%
# ────────────────────────────────────────────────────────────────────────────────
# Cell: Elbow → Cluster on top+bottom extremes → Overlay → Bar‐plot
# ────────────────────────────────────────────────────────────────────────────────
from sklearn.cluster import KMeans
from scipy.stats import friedmanchisquare
from scipy.spatial import ConvexHull
import matplotlib.patheffects as pe

# 1) POOL top-20 & bottom-20 coords from each fish
points = []
for f in fish_list:
    sal0, coords0, _ = plane0_data(f)
    idx_high = np.argsort(sal0)[-TOP_K:]
    idx_low  = np.argsort(sal0)[:TOP_K]
    sel      = np.hstack([idx_high, idx_low])
    points.append(coords0[sel])
xy_pool = np.vstack(points)  # shape (3*40, 2)

# 2) ELBOW PLOT (2…15) saved as elbow_plot.pdf
Ks, inertias = [], []
for k in range(2, 16):
    Ks.append(k)
    inertias.append(KMeans(n_clusters=k, random_state=0).fit(xy_pool).inertia_)
fig, ax = plt.subplots()
ax.plot(Ks, inertias, "-o")
ax.axvline(7, ls="--", c="red")
ax.set(xlabel="Clusters K", ylabel="Inertia")
fig.savefig(os.path.join(EXPT_DIR, "elbow_plot.pdf"),
            transparent=True, bbox_inches="tight")
plt.close(fig)
print("Elbow done—using K=7")

# 3) FINAL K-MEANS (K=7)
K_star = 8
km     = KMeans(n_clusters=K_star, random_state=0).fit(xy_pool)

# 4) ASSIGN & BUILD cluster_tables per fish
cluster_tables = []
for f in fish_list:
    sal0, coords0, _ = plane0_data(f)
    lbl = km.predict(coords0)
    cluster_tables.append(pd.DataFrame({
        "sal": sal0,
        "cl":  lbl,
        "x":   coords0[:,0],
        "y":   coords0[:,1]
    }))

# 5) RANK clusters A…G by descending mean-saliency
per_cl = np.vstack([tbl.groupby("cl")["sal"].mean().reindex(range(K_star)).values
                    for tbl in cluster_tables])
means = per_cl.mean(axis=0)
sems  = per_cl.std(axis=0, ddof=1)/np.sqrt(len(fish_list))
order = np.argsort(means)[::-1]
ABC   = list("ABCDEFG")[:K_star]
letter_map = {cl: ABC[i] for i, cl in enumerate(order)}
colors     = cm.tab10(np.arange(K_star)%10)

# 6) OVERLAY on fish11
tbl11 = cluster_tables[0]
bg11   = bright_plane0_image(11)

fig, ax = plt.subplots(figsize=(6,6))
ax.imshow(bg11, cmap="gray", vmin=0, vmax=1)
for cl in range(K_star):
    pts = tbl11.loc[tbl11["cl"]==cl, ["x","y"]].values
    if len(pts)==0: continue
    # scatter
    ax.scatter(pts[:,0], pts[:,1], s=30,
               c=[colors[cl]], edgecolors="white", alpha=0.8)
    # dotted hull
    if len(pts)>=3:
        hull = ConvexHull(pts)
        poly = pts[hull.vertices]
        ax.plot(*poly.T, ls=":", lw=1.5, c="white")
    # letter in white
    cx, cy = pts.mean(axis=0)
    ax.text(cx, cy, letter_map[cl], color="white", weight="bold",
            ha="center", va="center", fontsize=14,
            path_effects=[pe.Stroke(linewidth=3, foreground="black"),
                          pe.Normal()])

ax.axis("off"); fig.patch.set_alpha(0); ax.patch.set_alpha(0)
fig.savefig(os.path.join(EXPT_DIR, "fish11_clusters_overlay.pdf"),
            transparent=True, bbox_inches="tight")
plt.close(fig)
print("Saved fish11_clusters_overlay.pdf")

# 7) BAR PLOT (upward SEM-only) + Friedman test
data = np.vstack([
    tbl.groupby("cl")["sal"].mean().reindex(order).values
    for tbl in cluster_tables
])  # shape (3, 7)
means_ord = data.mean(axis=0)
sems_ord  = data.std(axis=0, ddof=1)/np.sqrt(len(fish_list))

yerr = [np.zeros_like(sems_ord), sems_ord]

fig, ax = plt.subplots(figsize=(8,4))
x = np.arange(K_star)
ax.bar(x, means_ord, yerr=yerr, capsize=5, color=colors[order])
ax.set_xticks(x)
ax.set_xticklabels(ABC[:K_star], fontsize=12)
ax.set_ylabel("Mean saliency (SEM ↑)")

# Friedman test
chi2, pval = friedmanchisquare(*[data[:,i] for i in range(K_star)])
ax.text(0.5, 0.90, f"Friedman p = {pval:.3f}",
        transform=ax.transAxes, ha="center", va="top", fontsize=10)

fig.patch.set_alpha(0)
fig.savefig(os.path.join(EXPT_DIR, "cluster_importance_barplot.pdf"),
            transparent=True, bbox_inches="tight")
plt.close(fig)
print("Saved cluster_importance_barplot.pdf")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 12
#      10 points = []
#      11 for f in fish_list:
# ---> 12     sal0, coords0, _ = plane0_data(f)
#      13     idx_high = np.argsort(sal0)[-TOP_K:]
#      14     idx_low  = np.argsort(sal0)[:TOP_K]
#
# Cell In[39], line 19, in plane0_data(fish_id)
#      17 img_dir = IMG_PATTERN.format(fish=fish_id)
#      18 h5 = os.path.join(img_dir, "functional_types_df.h5")
# ---> 19 df = pd.read_hdf(h5)
#      20 df0 = df[df["plane"] == "plane_0"]
#      21 sal0 = load_all_importances(fish_id)[df0.index.values.astype(int)]
#
# File ~\AppData\Roaming\jupyterlab-desktop\envs\fconn-holo\Lib\site-packages\pandas\io\pytables.py:452, in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     447                 raise ValueError(
#     448                     "key must be provided when HDF5 "
#     449                     "file contains multiple datasets."
#     450                 )
#     451         key = candidate_only_group._v_pathname
# --> 452     return store.select(
#     453         key,
#     454         where=where,
#     455         start=start,
#     456         stop=stop,
#     457         columns=columns,
#     458         iterator=iterator,
#     459         chunksize=chunksize,
#     460         auto_close=auto_close,
#     461     )
#     462 except (ValueError, TypeError, LookupError):
#     463     if not isinstance(path_or_buf, HDFStore):
#     464         # if there is an error, close the store if we opened it.
#
# File ~\AppData\Roaming\jupyterlab-desktop\envs\fconn-holo\Lib\site-packages\pandas\io\pytables.py:906, in HDFStore.select(self, key, where, start, stop, columns, iterator, chunksize, auto_close)
#     892 # create the iterator
#     893 it = TableIterator(
#     894     self,
#     895     s,
#    (...)    903     auto_close=auto_close,
#     904 )
# --> 906 return it.get_result()
#
# File ~\AppData\Roaming\jupyterlab-desktop\envs\fconn-holo\Lib\site-packages\pandas\io\pytables.py:2029, in TableIterator.get_result(self, coordinates)
#    2026     where = self.where
#    2028 # directly return the result
# -> 2029 results = self.func(self.start, self.stop, where)
#    2030 self.close()
#    2031 return results
#
# File ~\AppData\Roaming\jupyterlab-desktop\envs\fconn-holo\Lib\site-packages\pandas\io\pytables.py:890, in HDFStore.select.<locals>.func(_start, _stop, _where)
#     889 def func(_start, _stop, _where):
# --> 890     return s.read(start=_start, stop=_stop, where=_where, columns=columns)
#
# File ~\AppData\Roaming\jupyterlab-desktop\envs\fconn-holo\Lib\site-packages\pandas\io\pytables.py:3292, in BlockManagerFixed.read(self, where, columns, start, stop)
#    3290 for i in range(self.nblocks):
#    3291     blk_items = self.read_index(f"block{i}_items")
# -> 3292     values = self.read_array(f"block{i}_values", start=_start, stop=_stop)
#    3294     columns = items[items.get_indexer(blk_items)]
#    3295     df = DataFrame(values.T, columns=columns, index=axes[1], copy=False)
#
# File ~\AppData\Roaming\jupyterlab-desktop\envs\fconn-holo\Lib\site-packages\pandas\io\pytables.py:2956, in GenericFixed.read_array(self, key, start, stop)
#    2953 transposed = getattr(attrs, "transposed", False)
#    2955 if isinstance(node, tables.VLArray):
# -> 2956     ret = node[0][start:stop]
#    2957 else:
#    2958     dtype = _ensure_decoded(getattr(attrs, "value_type", None))
#
# File ~\AppData\Roaming\jupyterlab-desktop\envs\fconn-holo\Lib\site-packages\tables\vlarray.py:688, in VLArray.__getitem__(self, key)
#     686         key += self.nrows
#     687     (start, stop, step) = self._process_range(key, key + 1, 1)
# --> 688     return self.read(start, stop, step)[0]
#     689 elif isinstance(key, slice):
#     690     start, stop, step = self._process_range(
#     691         key.start, key.stop, key.step
#     692     )
#
# File ~\AppData\Roaming\jupyterlab-desktop\envs\fconn-holo\Lib\site-packages\tables\vlarray.py:840, in VLArray.read(self, start, stop, step)
#     838 atom = self.atom
#     839 if not hasattr(atom, "size"):  # it is a pseudo-atom
# --> 840     outlistarr = [atom.fromarray(arr) for arr in listarr]
#     841 else:
#     842     # Convert the list to the right flavor
#     843     flavor = self.flavor
#
# File ~\AppData\Roaming\jupyterlab-desktop\envs\fconn-holo\Lib\site-packages\tables\atom.py:1374, in ObjectAtom.fromarray(self, array)
#    1372 if array.size == 0:
#    1373     return None
# -> 1374 return pickle.loads(array.tobytes())
#
# File ~\AppData\Roaming\jupyterlab-desktop\envs\fconn-holo\Lib\site-packages\bcdict\bcdict.py:261, in BCDict.__getattr__(self, item)
#     259 def __getattr__(self, item: str) -> Any:
#     260     if (
# --> 261         item.startswith("_ipython_") or item.startswith(("_repr_"))
#     262     ) and self.__ipython_safe:
#     263         # prevent FormatterWarning in ipython notebooks
#     264         raise AttributeError()
#     265     return getattr(self.a, item)
#
# KeyboardInterrupt:
